# %%
#import the packages required
import pandas as pd
import numpy as np
import re
from scipy import sparse
from sklearn import preprocessing, linear_model
import sklearn.feature_extraction.text as txt

# %%
#read test and train dataset
train = pd.read_csv('TrainingData.csv')
test = pd.read_csv('TestData.csv')
sample = pd.read_csv('SubmissionFormat.csv')
# Out:
# C:\Users\derri\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#printing train and test dataset
print(train)
print(test)
# Out:
#         Unnamed: 0                                         Function  \
# 0           134338                             Teacher Compensation
# 1           206341                                         NO_LABEL
# 2           326408                             Teacher Compensation
# 3           364634                          Substitute Compensation
# 4            47683                          Substitute Compensation
# 5           229958                         Facilities & Maintenance
# 6           417668               Instructional Materials & Supplies
# 7           126378                                    Food Services
# 8           275539                             Teacher Compensation
# 9            85262                          Substitute Compensation
# 10          304569                                         NO_LABEL
# 11          330504               Instructional Materials & Supplies
# 12           84272                             Teacher Compensation
# 13           64760                                         NO_LABEL
# 14           21870                                         NO_LABEL
# 15           18698                          Substitute Compensation
# 16          169454               Instructional Materials & Supplies
# 17          169914                                Security & Safety
# 18          189701                                        Utilities
# 19           43727                                         NO_LABEL
# 20            5614                                         NO_LABEL
# 21          291539                          Substitute Compensation
# 22          307038                             Teacher Compensation
# 23           27645                                         NO_LABEL
# 24          126388                          Substitute Compensation
# 25           14962                             Teacher Compensation
# 26           84040                                         NO_LABEL
# 27           61639                          Substitute Compensation
# 28          266302                             Teacher Compensation
# 29          225768                           Student Transportation
# ...            ...                                              ...
# 400247      333748  Special Population Program Management & Support
# 400248      292626                                         NO_LABEL
# 400249      343458                          Substitute Compensation
# 400250      128261                             Teacher Compensation
# 400251      186318                             Teacher Compensation
# 400252      210652                          Substitute Compensation
# 400253      340354                               Aides Compensation
# 400254      435205                             Teacher Compensation
# 400255      174827                               Aides Compensation
# 400256      277504                             Teacher Compensation
# 400257      248062                         Professional Development
# 400258       70455                                         NO_LABEL
# 400259      203453                                         NO_LABEL
# 400260       58170                          Substitute Compensation
# 400261       72072                            School Administration
# 400262       68311                             Teacher Compensation
# 400263      225892                             Teacher Compensation
# 400264      446383                                         NO_LABEL
# 400265      155111                           Student Transportation
# 400266      278248               Instructional Materials & Supplies
# 400267      397424                                         NO_LABEL
# 400268      375092                          Substitute Compensation
# 400269      220181                                    Food Services
# 400270      307423                                         NO_LABEL
# 400271       46691                             Teacher Compensation
# 400272      109283                         Professional Development
# 400273      102430                          Substitute Compensation
# 400274      413949                     Parent & Community Relations
# 400275      433672                                  Library & Media
# 400276      415831                          Substitute Compensation
#
#                 Use                    Sharing   Reporting       Student_Type  \
# 0       Instruction            School Reported      School           NO_LABEL
# 1          NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 2       Instruction            School Reported      School        Unspecified
# 3       Instruction            School Reported      School        Unspecified
# 4       Instruction            School Reported      School        Unspecified
# 5               O&M            School Reported      School        Unspecified
# 6       Instruction            School Reported      School  Special Education
# 7               O&M  School on Central Budgets  Non-School        Unspecified
# 8       Instruction            School Reported      School        Unspecified
# 9       Instruction            School Reported      School        Unspecified
# 10         NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 11      Instruction            School Reported      School           NO_LABEL
# 12      Instruction            School Reported      School        Unspecified
# 13         NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 14         NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 15      Instruction            School Reported      School        Unspecified
# 16      Instruction            School Reported      School            Poverty
# 17              O&M    Leadership & Management  Non-School        Unspecified
# 18              O&M            School Reported      School        Unspecified
# 19         NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 20         NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 21      Instruction            School Reported      School        Unspecified
# 22      Instruction            School Reported      School            Poverty
# 23         NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 24      Instruction            School Reported      School        Unspecified
# 25      Instruction            School Reported      School            Poverty
# 26         NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 27      Instruction            School Reported      School        Unspecified
# 28      Instruction            School Reported      School        Unspecified
# 29              O&M            Shared Services  Non-School        Unspecified
# ...             ...                        ...         ...                ...
# 400247         ISPD  School on Central Budgets  Non-School  Special Education
# 400248     NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 400249  Instruction  School on Central Budgets  Non-School        Unspecified
# 400250  Instruction            School Reported      School  Special Education
# 400251  Instruction            School Reported      School        Unspecified
# 400252  Instruction            School Reported      School  Special Education
# 400253  Instruction            School Reported      School                ELL
# 400254  Instruction            School Reported      School        Unspecified
# 400255  Instruction            School Reported      School                ELL
# 400256  Instruction            School Reported      School        Unspecified
# 400257         ISPD            School Reported      School        Unspecified
# 400258     NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 400259     NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 400260  Instruction            School Reported      School        Unspecified
# 400261   Leadership            School Reported      School        Unspecified
# 400262  Instruction  School on Central Budgets  Non-School        Unspecified
# 400263  Instruction            School Reported      School        Unspecified
# 400264     NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 400265          O&M            Shared Services  Non-School        Unspecified
# 400266  Instruction            School Reported      School           NO_LABEL
# 400267     NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 400268  Instruction            School Reported      School        Unspecified
# 400269          O&M            Shared Services      School        Unspecified
# 400270     NO_LABEL                   NO_LABEL    NO_LABEL           NO_LABEL
# 400271  Instruction  School on Central Budgets  Non-School        Unspecified
# 400272         ISPD            Shared Services  Non-School        Unspecified
# 400273  Instruction            School Reported      School        Unspecified
# 400274     NO_LABEL            School Reported      School           NO_LABEL
# 400275  Instruction  School on Central Budgets  Non-School        Unspecified
# 400276  Instruction            School Reported      School            Poverty
#
#               Position_Type                 Object_Type     Pre_K  \
# 0                   Teacher                    NO_LABEL  NO_LABEL
# 1                  NO_LABEL                    NO_LABEL  NO_LABEL
# 2                   Teacher    Base Salary/Compensation  Non PreK
# 3                Substitute                    Benefits  NO_LABEL
# 4                   Teacher     Substitute Compensation  NO_LABEL
# 5                 Custodian                    Benefits  NO_LABEL
# 6              Non-Position          Supplies/Materials  NO_LABEL
# 7       Coordinator/Manager                    Benefits  NO_LABEL
# 8                   Teacher                    Benefits  NO_LABEL
# 9                Substitute                    Benefits  NO_LABEL
# 10                 NO_LABEL                    NO_LABEL  NO_LABEL
# 11                 NO_LABEL          Supplies/Materials  NO_LABEL
# 12                  Teacher    Base Salary/Compensation  Non PreK
# 13                 NO_LABEL                    NO_LABEL  NO_LABEL
# 14                 NO_LABEL                    NO_LABEL  NO_LABEL
# 15               Substitute     Substitute Compensation  Non PreK
# 16                 NO_LABEL          Supplies/Materials  NO_LABEL
# 17                    Other    Base Salary/Compensation  Non PreK
# 18             Non-Position              Rent/Utilities  NO_LABEL
# 19                 NO_LABEL                    NO_LABEL  NO_LABEL
# 20                 NO_LABEL                    NO_LABEL  NO_LABEL
# 21               Substitute    Base Salary/Compensation  NO_LABEL
# 22                  Teacher    Base Salary/Compensation  Non PreK
# 23                 NO_LABEL                    NO_LABEL  NO_LABEL
# 24               Substitute     Substitute Compensation  Non PreK
# 25                  Teacher    Base Salary/Compensation  Non PreK
# 26                 NO_LABEL                    NO_LABEL  NO_LABEL
# 27               Substitute                    Benefits  NO_LABEL
# 28                  Teacher                    Benefits  NO_LABEL
# 29                    Other  Other Compensation/Stipend  Non PreK
# ...                     ...                         ...       ...
# 400247         Psychologist    Base Salary/Compensation  Non PreK
# 400248             NO_LABEL                    NO_LABEL  NO_LABEL
# 400249           Substitute    Base Salary/Compensation  NO_LABEL
# 400250              Teacher    Base Salary/Compensation  NO_LABEL
# 400251              Teacher    Base Salary/Compensation  NO_LABEL
# 400252           Substitute     Substitute Compensation  Non PreK
# 400253                   TA                    Benefits  NO_LABEL
# 400254              Teacher                    Benefits  NO_LABEL
# 400255                   TA    Base Salary/Compensation  NO_LABEL
# 400256              Teacher                    Benefits  NO_LABEL
# 400257             NO_LABEL        Travel & Conferences  Non PreK
# 400258             NO_LABEL                    NO_LABEL  NO_LABEL
# 400259             NO_LABEL                    NO_LABEL  NO_LABEL
# 400260           Substitute     Substitute Compensation  Non PreK
# 400261       Vice Principal    Base Salary/Compensation  Non PreK
# 400262              Teacher  Other Compensation/Stipend  NO_LABEL
# 400263              Teacher    Base Salary/Compensation  NO_LABEL
# 400264             NO_LABEL                    NO_LABEL  NO_LABEL
# 400265                Other  Other Compensation/Stipend  Non PreK
# 400266             NO_LABEL          Supplies/Materials  NO_LABEL
# 400267             NO_LABEL                    NO_LABEL  NO_LABEL
# 400268           Substitute     Substitute Compensation  Non PreK
# 400269                Other    Base Salary/Compensation  Non PreK
# 400270             NO_LABEL                    NO_LABEL  NO_LABEL
# 400271              Teacher  Other Compensation/Stipend  NO_LABEL
# 400272  Instructional Coach  Other Compensation/Stipend  NO_LABEL
# 400273           Substitute    Base Salary/Compensation  NO_LABEL
# 400274                Other                    NO_LABEL  NO_LABEL
# 400275            Librarian                    Benefits  NO_LABEL
# 400276           Substitute     Substitute Compensation  Non PreK
#
#               Operating_Status  ...  \
# 0            PreK-12 Operating  ...
# 1                Non-Operating  ...
# 2            PreK-12 Operating  ...
# 3            PreK-12 Operating  ...
# 4            PreK-12 Operating  ...
# 5            PreK-12 Operating  ...
# 6            PreK-12 Operating  ...
# 7            PreK-12 Operating  ...
# 8            PreK-12 Operating  ...
# 9            PreK-12 Operating  ...
# 10               Non-Operating  ...
# 11           PreK-12 Operating  ...
# 12           PreK-12 Operating  ...
# 13               Non-Operating  ...
# 14      Operating, Not PreK-12  ...
# 15           PreK-12 Operating  ...
# 16           PreK-12 Operating  ...
# 17           PreK-12 Operating  ...
# 18           PreK-12 Operating  ...
# 19               Non-Operating  ...
# 20               Non-Operating  ...
# 21           PreK-12 Operating  ...
# 22           PreK-12 Operating  ...
# 23      Operating, Not PreK-12  ...
# 24           PreK-12 Operating  ...
# 25           PreK-12 Operating  ...
# 26               Non-Operating  ...
# 27           PreK-12 Operating  ...
# 28           PreK-12 Operating  ...
# 29           PreK-12 Operating  ...
# ...                        ...  ...
# 400247       PreK-12 Operating  ...
# 400248           Non-Operating  ...
# 400249       PreK-12 Operating  ...
# 400250       PreK-12 Operating  ...
# 400251       PreK-12 Operating  ...
# 400252       PreK-12 Operating  ...
# 400253       PreK-12 Operating  ...
# 400254       PreK-12 Operating  ...
# 400255       PreK-12 Operating  ...
# 400256       PreK-12 Operating  ...
# 400257       PreK-12 Operating  ...
# 400258  Operating, Not PreK-12  ...
# 400259           Non-Operating  ...
# 400260       PreK-12 Operating  ...
# 400261       PreK-12 Operating  ...
# 400262       PreK-12 Operating  ...
# 400263       PreK-12 Operating  ...
# 400264           Non-Operating  ...
# 400265       PreK-12 Operating  ...
# 400266       PreK-12 Operating  ...
# 400267           Non-Operating  ...
# 400268       PreK-12 Operating  ...
# 400269       PreK-12 Operating  ...
# 400270           Non-Operating  ...
# 400271       PreK-12 Operating  ...
# 400272       PreK-12 Operating  ...
# 400273       PreK-12 Operating  ...
# 400274       PreK-12 Operating  ...
# 400275       PreK-12 Operating  ...
# 400276       PreK-12 Operating  ...
#
#                                Sub_Object_Description  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                        Equipment *
# 11                                                NaN
# 12                                                NaN
# 13          Certificated Employees Salaries And Wages
# 14                                                NaN
# 15         Salaries And Wages For Substitute Teachers
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                   Travel Mileage/Meeting Expense *
# 20                                 Purchased Services
# 21                                                NaN
# 22          Certificated Employees Salaries And Wages
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                        Equipment *
# 27                                                NaN
# 28                                                NaN
# 29      Extra Duty Pay/Overtime For Support Personnel
# ...                                               ...
# 400247      Certificated Employees Salaries And Wages
# 400248  Extra Duty Pay/Overtime For Support Personnel
# 400249                                            NaN
# 400250                                            NaN
# 400251                                            NaN
# 400252                                            NaN
# 400253                                            NaN
# 400254                                            NaN
# 400255                                            NaN
# 400256                                            NaN
# 400257         Travel And Subsistence - Employee Only
# 400258                                            NaN
# 400259                                            NaN
# 400260                                            NaN
# 400261                                            NaN
# 400262                                            NaN
# 400263                                            NaN
# 400264                         Pupil Transportation *
# 400265  Extra Duty Pay/Overtime For Support Personnel
# 400266                                            NaN
# 400267                                            NaN
# 400268                                            NaN
# 400269        Salaries Or Wages For Support Personnel
# 400270                            Awards And Prizes *
# 400271                                            NaN
# 400272                                            NaN
# 400273                                            NaN
# 400274                                            NaN
# 400275                                            NaN
# 400276     Inservice Substitute Teachers Grant Funded
#
#                   Location_Description       FTE  \
# 0                                  NaN  1.000000
# 1                                  NaN       NaN
# 2                                  NaN  1.000000
# 3                                  NaN       NaN
# 4                                  NaN       NaN
# 5                                  NaN       NaN
# 6                                  NaN       NaN
# 7       DISTRICT WIDE ORGANIZATION UNI       NaN
# 8                                  NaN       NaN
# 9                                  NaN       NaN
# 10                                 NaN       NaN
# 11                                 NaN       NaN
# 12                                 NaN  0.600000
# 13                                 NaN       NaN
# 14                             CHARTER  0.000000
# 15                             School        NaN
# 16                             School        NaN
# 17        SAFETY AND SECURITY DIVISION  1.000000
# 18                                 NaN       NaN
# 19                                 NaN       NaN
# 20                                 NaN       NaN
# 21                                 NaN  0.012931
# 22          SR OTH CERTIFICATED PERSON  1.000000
# 23                             CHARTER       NaN
# 24                                 NaN  0.000000
# 25                                 NaN  1.000000
# 26                                 NaN       NaN
# 27                                 NaN       NaN
# 28                                 NaN       NaN
# 29                       Undistributed       NaN
# ...                                ...       ...
# 400247      PSYCHOLOGICAL SERVICES OFF  1.000000
# 400248                     Unallocated       NaN
# 400249       ALL SCHOOLS-UNDISTRIBUTED       NaN
# 400250                             NaN       NaN
# 400251                             NaN  1.000025
# 400252                             NaN  0.000000
# 400253                             NaN       NaN
# 400254                             NaN       NaN
# 400255                             NaN       NaN
# 400256                             NaN       NaN
# 400257                         School        NaN
# 400258                         School   1.000000
# 400259                         School        NaN
# 400260                             NaN  0.000000
# 400261                             NaN  1.000000
# 400262                  MATH / SCIENCE       NaN
# 400263                             NaN       NaN
# 400264                             NaN       NaN
# 400265                     Unallocated       NaN
# 400266                             NaN       NaN
# 400267                             NaN       NaN
# 400268                             NaN  0.000000
# 400269                         School   0.090000
# 400270                             NaN       NaN
# 400271                  MATH / SCIENCE       NaN
# 400272  STAFF DEV AND INSTR MEDIA            NaN
# 400273                             NaN  0.004310
# 400274                             NaN  1.000000
# 400275            ED RESOURCE SERVICES       NaN
# 400276                         School        NaN
#
#                                      Function_Description  \
# 0                                                     NaN
# 1                                                RGN  GOB
# 2                                                     NaN
# 3                                 UNALLOC BUDGETS/SCHOOLS
# 4                                             NON-PROJECT
# 5                                             NON-PROJECT
# 6                                                     NaN
# 7                                             NON-PROJECT
# 8                           ELA S - TEACHING SPANISH ONLY
# 9                                 UNALLOC BUDGETS/SCHOOLS
# 10      State and Federal Projects Coordination Services*
# 11                                            INSTRUCTION
# 12                                                    NaN
# 13                                  Disadvantaged Youth *
# 14                         BASIC (FEFP K-12)
# 15                                            Instruction
# 16                         BASIC (FEFP K-12)
# 17                                      Security Services
# 18                                            NON-PROJECT
# 19      Instruction And Curriculum Development Services *
# 20               Direction Of Support Services - Pupils *
# 21                                UNALLOC BUDGETS/SCHOOLS
# 22                                  Disadvantaged Youth *
# 23                         GUIDANCE SERVICES
# 24                                                    NaN
# 25                                                    NaN
# 26      Instruction And Curriculum Development Services *
# 27                                           CORE MATTERS
# 28                           ELA E-TEACHING SHELTERED ENG
# 29                                         Transportation
# ...                                                   ...
# 400247                           Psychological Services *
# 400248            Facilities Acquisition And Construction
# 400249                            UNALLOC BUDGETS/SCHOOLS
# 400250                         SPECIAL ED. - SEVERE NEEDS
# 400251                      ELA S - TEACHING SPANISH ONLY
# 400252                                                NaN
# 400253                                     TITLE III  ELA
# 400254                        READ TO ACHIEVE ROUND THREE
# 400255                                            TITLE I
# 400256                                        NON-PROJECT
# 400257  Curriculum Development And Instructional Staff...
# 400258                     BASIC (FEFP K-12)
# 400259                     STAFF SERVICES
# 400260                                                NaN
# 400261                                                NaN
# 400262                     TITLE II-PART A-TEACHER QUALIT
# 400263                       ELA E-TEACHING SHELTERED ENG
# 400264  Instruction And Curriculum Development Services *
# 400265                                     Transportation
# 400266                                        INSTRUCTION
# 400267                                            NS  GOB
# 400268                                                NaN
# 400269          Food Services (Child Nutrition Fund Only)
# 400270       Other Improvements Of Instruction Services *
# 400271                     TITLE II-PART A-TEACHER QUALIT
# 400272                     INST STAFF TRAINING SVCS
# 400273                                         TITLE II,D
# 400274                                                NaN
# 400275                                        NON-PROJECT
# 400276                                        Instruction
#
#                             Facility_or_Department  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                          POSITION CONTROL POOLS
# 13                                             NaN
# 14                                             NaN
# 15                              All Campus Payroll
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                             NaN
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
# 24                                             NaN
# 25                                             NaN
# 26                                             NaN
# 27                                             NaN
# 28                                             NaN
# 29                       Transportation Department
# ...                                            ...
# 400247                                         NaN
# 400248  New Construction Department Administration
# 400249                                         NaN
# 400250                                         NaN
# 400251                                         NaN
# 400252                              TEACHER SUPPLY
# 400253                                         NaN
# 400254                                         NaN
# 400255                                         NaN
# 400256                                         NaN
# 400257                                  Vocational
# 400258                                         NaN
# 400259                                         NaN
# 400260                                         NaN
# 400261                                         NaN
# 400262                                         NaN
# 400263                                         NaN
# 400264                                         NaN
# 400265                   Transportation Department
# 400266                                         NaN
# 400267                                         NaN
# 400268                                         NaN
# 400269                             Child Nutrition
# 400270                                         NaN
# 400271                                         NaN
# 400272                                         NaN
# 400273                                         NaN
# 400274                                         NaN
# 400275                                         NaN
# 400276                  Instruction And Curriculum
#
#                        Position_Extra          Total  \
# 0                       KINDERGARTEN    50471.810000
# 1                        UNDESIGNATED    3477.860000
# 2                             TEACHER   62237.130000
# 3          PROFESSIONAL-INSTRUCTIONAL      22.300000
# 4          PROFESSIONAL-INSTRUCTIONAL      54.166000
# 5                        UNDESIGNATED      -8.150000
# 6              SUPPLIES AND MATERIALS    2000.050000
# 7                        UNDESIGNATED       0.720000
# 8          PROFESSIONAL-INSTRUCTIONAL     228.250000
# 9          PROFESSIONAL-INSTRUCTIONAL      69.560000
# 10                                NaN   -5509.320000
# 11                                NaN      16.410000
# 12                            TEACHER   38824.790000
# 13                                NaN -122544.070000
# 14                                NaN     228.530000
# 15                 DEGREED SUBSTITUTE      94.357986
# 16                                NaN     146.510000
# 17                                NaN   66651.255981
# 18                       UNDESIGNATED   30382.320000
# 19                                NaN    -446.110000
# 20                                NaN     550.310000
# 21         PROFESSIONAL-INSTRUCTIONAL     329.353815
# 22                                NaN  103318.698037
# 23                                NaN     649.860000
# 24                 SUBSTITUTE TEACHER      71.140000
# 25                    TEACHER -  DAYS   17101.770000
# 26                                NaN  -21795.930000
# 27         PROFESSIONAL-INSTRUCTIONAL       1.120000
# 28         PROFESSIONAL-INSTRUCTIONAL    5037.240000
# 29                         BUS DRIVER     201.680000
# ...                               ...            ...
# 400247                            NaN  108879.445586
# 400248         DIR EXEC DIR SECRETARY      34.720000
# 400249     PROFESSIONAL-INSTRUCTIONAL     107.459600
# 400250     PROFESSIONAL-INSTRUCTIONAL    2191.170000
# 400251     PROFESSIONAL-INSTRUCTIONAL   48618.855433
# 400252             SUBSTITUTE TEACHER     111.960000
# 400253               PARAPROFESSIONAL     791.520000
# 400254     PROFESSIONAL-INSTRUCTIONAL     503.490000
# 400255               PARAPROFESSIONAL      37.824320
# 400256                   UNDESIGNATED    -838.820000
# 400257                            NaN    1830.860000
# 400258                            NaN   71846.661087
# 400259                            NaN      28.000000
# 400260             SUBSTITUTE TEACHER      71.310000
# 400261                 ASST PRINCIPAL   65258.960000
# 400262     PROFESSIONAL-INSTRUCTIONAL     142.124320
# 400263     PROFESSIONAL-INSTRUCTIONAL    2834.496320
# 400264                            NaN   -7725.350000
# 400265     RADIO & SUBSTITUTE DRIVERS     759.340000
# 400266                            NaN      74.590000
# 400267               PARAPROFESSIONAL     157.654000
# 400268             SUBSTITUTE TEACHER     141.939900
# 400269       REG FOOD SERVICE WORKER     2293.931767
# 400270                            NaN    -390.710000
# 400271     PROFESSIONAL-INSTRUCTIONAL     283.988640
# 400272                            NaN      48.620000
# 400273     PROFESSIONAL-INSTRUCTIONAL     128.824985
# 400274                 PARENT/TITLE I    4902.290000
# 400275  OFFICE/ADMINISTRATIVE SUPPORT    4020.290000
# 400276           CERTIFIED SUBSTITUTE      46.530000
#
#                                       Program_Description  \
# 0                                            KINDERGARTEN
# 1                           BUILDING IMPROVEMENT SERVICES
# 2                                   Instruction - Regular
# 3                          GENERAL MIDDLE/JUNIOR HIGH SCH
# 4                           GENERAL HIGH SCHOOL EDUCATION
# 5                                       EMPLOYEE BENEFITS
# 6                                 SPECIAL EDUCATION LOCAL
# 7                                            UNDESIGNATED
# 8                            GENERAL ELEMENTARY EDUCATION
# 9                            GENERAL ELEMENTARY EDUCATION
# 10                                                    NaN
# 11                                PRIMARY GRADES PROGRAM
# 12                                  Instruction - Regular
# 13                                                    NaN
# 14                                                    NaN
# 15      Bilingual Education And Special Language Programs
# 16                                                    NaN
# 17                                                    NaN
# 18                         CARE & UPKEEP OF BLDG SERVICES
# 19                                                    NaN
# 20                                                    NaN
# 21                           GENERAL ELEMENTARY EDUCATION
# 22                                                    NaN
# 23                                                    NaN
# 24                                  Instruction - Regular
# 25                                  Instruction - Regular
# 26                                                    NaN
# 27                           INSTRUCTIONAL STAFF TRAINING
# 28                           GENERAL ELEMENTARY EDUCATION
# 29                                          Undistributed
# ...                                                   ...
# 400247                                                NaN
# 400248                                      Undistributed
# 400249                            OTHER GENERAL EDUCATION
# 400250                         SPECIAL EDUCATION-TMD HIGH
# 400251                       GENERAL ELEMENTARY EDUCATION
# 400252                                 Instruction - SPED
# 400253                      GENERAL HIGH SCHOOL EDUCATION
# 400254                       GENERAL ELEMENTARY EDUCATION
# 400255                       GENERAL ELEMENTARY EDUCATION
# 400256                                  EMPLOYEE BENEFITS
# 400257                              Career And Technology
# 400258                                                NaN
# 400259                                                NaN
# 400260                      Support - Regular Instruction
# 400261                                 Principal's Office
# 400262                       INSTRUCTIONAL STAFF TRAINING
# 400263                       GENERAL ELEMENTARY EDUCATION
# 400264                                                NaN
# 400265                                      Undistributed
# 400266                            PRIMARY GRADES PROGRAM
# 400267                     GENERAL MIDDLE/JUNIOR HIGH SCH
# 400268                              Instruction - Regular
# 400269                                      Undistributed
# 400270                                                NaN
# 400271                       INSTRUCTIONAL STAFF TRAINING
# 400272                                                NaN
# 400273                       INSTRUCTIONAL STAFF TRAINING
# 400274                                               Misc
# 400275                             MEDIA SUPPORT SERVICES
# 400276                              Accelerated Education
#
#                                          Fund_Description  \
# 0                                            General Fund
# 1                                                     NaN
# 2                                  General Purpose School
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                              LOCAL FUND
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                         School to Work
# 11                                           General Fund
# 12                                 General Purpose School
# 13      Title I - Disadvantaged Children/Targeted Assi...
# 14                         CONVERSION CHARTER SCHOOLS
# 15                                 General Operating Fund
# 16                         GENERAL FUND
# 17                                                General
# 18                                                    NaN
# 19                                          Special Trust
# 20                                          Special Trust
# 21                                                    NaN
# 22      Title I - Disadvantaged Children/Targeted Assi...
# 23                         CONVERSION CHARTER SCHOOLS
# 24                                 General Purpose School
# 25                                School Federal Projects
# 26                                          Special Trust
# 27                                                    NaN
# 28                                                    NaN
# 29                                 General Operating Fund
# ...                                                   ...
# 400247                                            General
# 400248                             General Operating Fund
# 400249                                                NaN
# 400250                                                NaN
# 400251                                                NaN
# 400252                            School Federal Projects
# 400253                                                NaN
# 400254                                                NaN
# 400255                                                NaN
# 400256                                                NaN
# 400257                             General Operating Fund
# 400258                     CONVERSION CHARTER SCHOOLS
# 400259                     EXTENDED LEARNING CENTER ELC
# 400260                            School Federal Projects
# 400261                             General Purpose School
# 400262                                                NaN
# 400263                                                NaN
# 400264                                      Special Trust
# 400265                             General Operating Fund
# 400266                                       General Fund
# 400267                                                NaN
# 400268                             General Purpose School
# 400269        National School Breakfast And Lunch Program
# 400270                         Miscellaneous State Grants
# 400271                                                NaN
# 400272                     GENERAL FUND
# 400273                                                NaN
# 400274                                 Schoolwide Schools
# 400275                                                NaN
# 400276           "Title  Part A Improving Basic Programs"
#
#                                           Text_1
# 0                                            NaN
# 1                  BUILDING IMPROVEMENT SERVICES
# 2                                            NaN
# 3                            REGULAR INSTRUCTION
# 4                            REGULAR INSTRUCTION
# 5                              EMPLOYEE BENEFITS
# 6                                            NaN
# 7                                   UNDESIGNATED
# 8                            REGULAR INSTRUCTION
# 9                            REGULAR INSTRUCTION
# 10                    ITEMAI-CITY-YTH EMP & OPP
# 11                                           NaN
# 12                                           NaN
# 13                                      TITLE I
# 14                                           NaN
# 15                                   REGULAR PAY
# 16                TEACHER LEAD
# 17                             SAFETY & SECURITY
# 18                  OPERATION AND MAINT OF PLANT
# 19                         RESP SEXUAL BEHAVIOR
# 20                          HOME TEAM MARKETING
# 21                           REGULAR INSTRUCTION
# 22                          BUILDING ALLOCATIONS
# 23                                           NaN
# 24                                           NaN
# 25                    ESEA TITLE I DISADVANTAGED
# 26                     KEY BANK NATIONAL ASSOCIA
# 27                           INSTRUCTIONAL STAFF
# 28                           REGULAR INSTRUCTION
# 29                 ADDL REGULAR PAY-NOT SMOOTHED
# ...                                          ...
# 400247                    PSYCHOLOGICAL SERVICES
# 400248                                  OVERTIME
# 400249                       REGULAR INSTRUCTION
# 400250                         SPECIAL EDUCATION
# 400251                       REGULAR INSTRUCTION
# 400252  INDIVIDUALS WITH DISABILITIES ACT PART B
# 400253                       REGULAR INSTRUCTION
# 400254                       REGULAR INSTRUCTION
# 400255                       REGULAR INSTRUCTION
# 400256                         EMPLOYEE BENEFITS
# 400257                                       NaN
# 400258                                       NaN
# 400259                                       NaN
# 400260                                     OTHER
# 400261                                       NaN
# 400262                       INSTRUCTIONAL STAFF
# 400263                       REGULAR INSTRUCTION
# 400264                    ITEMS FOUNDATION-JUNE
# 400265                                  OVERTIME
# 400266                                       NaN
# 400267                       REGULAR INSTRUCTION
# 400268                                       NaN
# 400269                               REGULAR PAY
# 400270                  SCHOOL IMPROV INCENTIVES
# 400271                       INSTRUCTIONAL STAFF
# 400272            STAFF DEV AND INSTR MEDIA
# 400273                       INSTRUCTIONAL STAFF
# 400274                                       NaN
# 400275                       INSTRUCTIONAL STAFF
# 400276                            MISCELLANEOUS
#
# [400277 rows x 26 columns]
#        Unnamed: 0                                 Object_Description  \
# 0          180042                           Student Meals/Room/Other
# 1           28872                       Extra Duty/Signing Bonus Pay
# 2          186915                              Professional Salaries
# 3          412396                              Professional Salaries
# 4          427740                     Salaries for Support Personnel
# 5           69847                                   General Supplies
# 6          358824                                    Maint: Vehicles
# 7          254148                       Extra Duty/Signing Bonus Pay
# 8             296                                   General Supplies
# 9          416755                     Salaries for Support Personnel
# 10         179714                     Salaries for Support Personnel
# 11         285896                     Salaries for Support Personnel
# 12         265808          Reading Materials including Library Books
# 13         197775                              Professional Salaries
# 14         204524                       Extra Duty/Signing Bonus Pay
# 15         229744                              Professional Salaries
# 16          30711                                 Employee Allowance
# 17         220894                                   Part-Time Hourly
# 18           7061                     Salaries for Support Personnel
# 19           4824                                   Part-Time Hourly
# 20         153530                                   Part-Time Hourly
# 21         257139                                                NaN
# 22         268606                              Professional Salaries
# 23         146084                              Professional Salaries
# 24         178313                                 Employee Allowance
# 25         371096                              Professional Salaries
# 26          89815                                   General Supplies
# 27         395364                                   General Supplies
# 28         367109                              Professional Salaries
# 29         144432                              Professional Salaries
# ...           ...                                                ...
# 50034      108573  Salaries And Wages For Teachers And Other Prof...
# 50035      100467      Extra Duty Pay/Overtime For Support Personnel
# 50036      116570  Salaries And Wages For Teachers And Other Prof...
# 50037      370029            Salaries Or Wages For Support Personnel
# 50038      268829    Salaries And Wages For Substitute Professionals
# 50039      323389  Salaries And Wages For Teachers And Other Prof...
# 50040      154866                      Miscellaneous Operating Costs
# 50041       97996  Salaries And Wages For Teachers And Other Prof...
# 50042      263939  Salaries And Wages For Teachers And Other Prof...
# 50043      155078  Salaries And Wages For Teachers And Other Prof...
# 50044       86286  Salaries And Wages For Teachers And Other Prof...
# 50045      185421  Salaries And Wages For Teachers And Other Prof...
# 50046      215167      Extra Duty Pay/Overtime For Support Personnel
# 50047      324001  Salaries And Wages For Teachers And Other Prof...
# 50048      309998                                   General Supplies
# 50049      345702  Salaries And Wages For Teachers And Other Prof...
# 50050      185199                                   General Supplies
# 50051      267450                                 Teacher Retirement
# 50052      421320  Salaries And Wages For Teachers And Other Prof...
# 50053       11773      Extra Duty Pay/Overtime For Support Personnel
# ...
# 15                                        Instruction
# 16                                        Instruction
# 17                                 Community Services
# 18                           Instructional Leadership
# 19                    Security & Monitoring Servicess
# 20         Cocurricular & Extra Curricular Activities
# 21                                        Instruction
# 22                                        Instruction
# 23                                        Instruction
# 24                           Data Processing Services
# 25                                  School Leadership
# 26                                        Instruction
# 27         Cocurricular & Extra Curricular Activities
# 28       Curriculum & Instructional Staff Development
# 29                                        Instruction
# ...                                               ...
# 50034                                     Instruction
# 50035           Facilities Maintenance And Operations
# 50036                                     Instruction
# 50037                                     Instruction
# 50038                                     Instruction
# 50039                                     Instruction
# 50040                      Extracurricular Activities
# 50041                                     Instruction
# 50042                                     Instruction
# 50043                                     Instruction
# 50044                                     Instruction
# 50045                                     Instruction
# 50046                                     Instruction
# 50047                                     Instruction
# 50048                      Extracurricular Activities
# 50049                      Extracurricular Activities
# 50050                                     Instruction
# 50051  "Guidance, Counseling And Evaluation Services"
# 50052                                     Instruction
# 50053                                  Transportation
# 50054           Facilities Maintenance And Operations
# 50055           Facilities Maintenance And Operations
# 50056       Food Services (Child Nutrition Fund Only)
# 50057           Facilities Maintenance And Operations
# 50058                               School Leadership
# 50059                                             NaN
# 50060                                             NaN
# 50061                                             NaN
# 50062                                             NaN
# 50063                                             NaN
#
#                  Position_Extra  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                          NaN
# 27                          NaN
# 28                          NaN
# 29                          NaN
# ...                         ...
# 50034          TEACHER BACHELOR
# 50035               CO CLERICAL
# 50036          TEACHER BACHELOR
# 50037                      AIDE
# 50038      CERTIFIED SUBSTITUTE
# 50039          TEACHER BACHELOR
# 50040                       NaN
# 50041          TEACHER BACHELOR
# 50042            TEACHER MASTER
# 50043          TEACHER BACHELOR
# 50044          TEACHER BACHELOR
# 50045          TEACHER BACHELOR
# 50046                      AIDE
# 50047          TEACHER BACHELOR
# 50048                       NaN
# 50049            TEACHER MASTER
# 50050                       NaN
# 50051                       NaN
# 50052                  TUTORING
# 50053                BUS DRIVER
# 50054   HEAD CUS REG SIZE ELEM
# 50055           COLLEGE STUDENT
# 50056  REG FOOD SERVICE WORKER
# 50057                       NaN
# 50058                       NaN
# 50059         CLINIC ASSISTANT
# 50060         CLINIC ASSISTANT
# 50061         CLINIC ASSISTANT
# 50062         CLINIC ASSISTANT
# 50063         CLINIC ASSISTANT
#
#                                                  Text_4          Total Text_2  \
# 0                                                   NaN    3999.910000    NaN
# 1                                                   NaN    3447.320213    NaN
# 2                                                   NaN   52738.780869    NaN
# 3                                                   NaN   69729.263191    NaN
# 4                                                   NaN   29492.834215    NaN
# 5                                                   NaN     611.730000    NaN
# 6                                                   NaN   45999.960000    NaN
# 7                                                   NaN    9342.409000    NaN
# 8                                                   NaN    1480.970000    NaN
# 9                                                   NaN   13675.591718    NaN
# 10                                                  NaN   38206.268900    NaN
# 11                                                  NaN   30583.746336    NaN
# 12                                                  NaN     650.720000    NaN
# 13                                                  NaN   57037.432709    NaN
# 14                                                  NaN   11450.850204    NaN
# 15                                                  NaN   56226.718197    NaN
# 16                                                  NaN     433.267707    NaN
# 17                                                  NaN   49792.634000    NaN
# 18                                                  NaN   21998.639555    NaN
# 19                                                  NaN    4963.147023    NaN
# 20                                                  NaN   53608.108232    NaN
# 21                                                  NaN     471.140000    NaN
# 22                                                  NaN   70652.889648    NaN
# 23                                                  NaN   35486.471566    NaN
# 24                                                  NaN    2634.483304    NaN
# 25                                                  NaN   33498.108019    NaN
# 26                                                  NaN    1000.610000    NaN
# 27                                                  NaN     499.370000    NaN
# 28                                                  NaN   71303.569686    NaN
# 29                                                  NaN   53436.910216    NaN
# ...                                                 ...            ...    ...
# 50034                                               NaN    1356.540972    NaN
# 50035                                               NaN    1401.860000    NaN
# 50036  Basic Educational Services - District Objective    70570.579724    NaN
# 50037                                               NaN   19130.342458    NaN
# 50038                                               NaN      99.474652    NaN
# 50039  Basic Educational Services - District Objective      250.470000    NaN
# 50040                                               NaN    -200.190000    NaN
# 50041  Basic Educational Services - District Objective    55106.075988    NaN
# 50042                                               NaN    1563.031091    NaN
# 50043  Basic Educational Services - District Objective    54814.807695    NaN
# 50044                                               NaN     104.991210    NaN
# 50045  Basic Educational Services - District Objective    53295.277768    NaN
# 50046                                               NaN     134.990000    NaN
# 50047                                               NaN     260.580426    NaN
# 50048                                               NaN    6203.160000    NaN
# 50049                                     Undistributed     520.815198    NaN
# 50050                                               NaN    5522.160000    NaN
# 50051                                        Extra Duty      69.410000    NaN
# 50052                                               NaN    3536.420000    NaN
# 50053                      transportation - Second Runs     277.350000    NaN
# 50054                                               NaN     449.620000    NaN
# 50055                                               NaN     939.374591    NaN
# 50056                                     Undistributed   17116.229073    NaN
# 50057                                               NaN  572109.800000    NaN
# 50058                                               NaN    3524.800000    NaN
# 50059                                               NaN    1542.840000    NaN
# 50060                                               NaN    9943.970000    NaN
# 50061                                               NaN   14674.360000    NaN
# 50062                                               NaN   11006.140000    NaN
# 50063                                               NaN   14434.350000    NaN
#
#       Text_3                                Fund_Description  \
# 0        NaN                                    General Fund
# 1        NaN                                    General Fund
# 2        NaN                                    General Fund
# 3        NaN                                    General Fund
# 4        NaN                                    General Fund
# 5        NaN                                    General Fund
# 6        NaN                                    General Fund
# 7        NaN                                  IDEA-B Formula
# 8        NaN                                    General Fund
# 9        NaN              Nat'l Schl Breakfast & Lunch Prog.
# 10       NaN                                    General Fund
# 11       NaN                                  IDEA-B Formula
# 12       NaN                                    General Fund
# 13       NaN                                    General Fund
# 14       NaN                                    General Fund
# 15       NaN                                    General Fund
# 16       NaN                                    General Fund
# 17       NaN                         English Literacy Civics
# 18       NaN                                    General Fund
# 19       NaN                                    General Fund
# 20       NaN                                       Athletics
# 21       NaN                                    General Fund
# 22       NaN                                    General Fund
# 23       NaN                                    General Fund
# 24       NaN                                    General Fund
# 25       NaN                                    General Fund
# 26       NaN                                    General Fund
# 27       NaN                                       Athletics
# 28       NaN                                 Title I- Part A
# 29       NaN                                    General Fund
# ...      ...                                             ...
# 50034    NaN        "Title  Part A Improving Basic Programs"
# 50035    NaN                          General Operating Fund
# 50036    NaN                          General Operating Fund
# 50037    NaN                          General Operating Fund
# 50038    NaN                          General Operating Fund
# 50039    NaN  Intensive Reading Instruction Initiative Grant
# 50040    NaN                           Campus Activity Funds
# 50041    NaN                          General Operating Fund
# 50042    NaN                          General Operating Fund
# 50043    NaN                          General Operating Fund
# 50044    NaN        "Title  Part A Improving Basic Programs"
# 50045    NaN                          General Operating Fund
# 50046    NaN                           Campus Activity Funds
# 50047    NaN        "Title  Part A Improving Basic Programs"
# 50048    NaN                          General Operating Fund
# 50049    NaN                          General Operating Fund
# 50050    NaN                          General Operating Fund
# 50051    NaN                             Idea Part B Formula
# 50052    NaN        "Title  Part A Improving Basic Programs"
# 50053    NaN                          General Operating Fund
# 50054    NaN                          General Operating Fund
# 50055    NaN                          General Operating Fund
# 50056    NaN     National School Breakfast And Lunch Program
# 50057    NaN                          General Operating Fund
# 50058    NaN                           Campus Activity Funds
# 50059    NaN                                    General Fund
# 50060    NaN                                    General Fund
# 50061    NaN                                    General Fund
# 50062    NaN                                    General Fund
# 50063    NaN                                    General Fund
#
#                           Text_1
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# ...                          ...
# 50034              EXTENDED YEAR
# 50035                   OVERTIME
# 50036                REGULAR PAY
# 50037                REGULAR PAY
# 50038                REGULAR PAY
# 50039             MISCELLANEOUS
# 50040                        NaN
# 50041                REGULAR PAY
# 50042  CRITICAL NEEDS SUPPLEMENT
# 50043                REGULAR PAY
# 50044             MISCELLANEOUS
# 50045                REGULAR PAY
# 50046              EXTENDED DAYS
# 50047              EXTENDED DAYS
# 50048                        NaN
# 50049            PREFORMANCE PAY
# 50050                        NaN
# 50051                        NaN
# 50052              EXTENDED DAYS
# 50053                  EXTRA RUN
# 50054                   OVERTIME
# 50055                REGULAR PAY
# 50056                REGULAR PAY
# 50057                        NaN
# 50058                        NaN
# 50059                        NaN
# 50060                        NaN
# 50061                        NaN
# 50062                        NaN
# 50063                        NaN
#
# [50064 rows x 17 columns]

# %%
training_data = train[['FTE','Facility_or_Department', 'Function_Description','Fund_Description',
                       'Job_Title_Description', 'Location_Description','Object_Description',
                       'Position_Extra', 'Program_Description', 'SubFund_Description',
                       'Sub_Object_Description', 'Text_1', 'Text_2','Text_3','Text_4', 'Total']]

cols = ['Function','Object_Type','Operating_Status','Position_Type','Pre_K', 'Reporting',
                'Sharing','Student_Type', 'Use']

labels = train[cols]

it=['Facility_or_Department', 'Function_Description','Fund_Description',
                       'Job_Title_Description', 'Location_Description','Object_Description',
                       'Position_Extra', 'Program_Description', 'SubFund_Description',
                       'Sub_Object_Description', 'Text_1', 'Text_2','Text_3','Text_4']
test_data = test[['FTE','Facility_or_Department', 'Function_Description','Fund_Description',
                       'Job_Title_Description', 'Location_Description','Object_Description',
                       'Position_Extra', 'Program_Description', 'SubFund_Description',
                       'Sub_Object_Description', 'Text_1', 'Text_2','Text_3','Text_4', 'Total']]

# %%
#data cleaning
def clean(s):
    try:
        return " ".join(re.findall(r'\w+', s)).lower()
    except:
        return " ".join(re.findall(r'\w+', "no_text")).lower()

# %%
#encoding labels

label_encoder = preprocessing.LabelEncoder()
for i in cols:
    labels[i] = label_encoder.fit_transform(np.array(labels[i]))
# Out:
# C:\Users\derri\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
#drop columns which has non text values
training_data = training_data.drop('FTE', axis = 1)
training_data = training_data.drop('Total', axis = 1)

test_data = test_data.drop('FTE', axis = 1)
test_data = test_data.drop('Total', axis = 1)



for i in it:
        training_data[i] = training_data[i].apply(clean)
for i in it:
        test_data[i] = test_data[i].apply(clean)

# %%
#printing training and testing data
print(training_data)
print(test_data)
# Out:
#                             Facility_or_Department  \
# 0                                          no_text
# 1                                          no_text
# 2                                          no_text
# 3                                          no_text
# 4                                          no_text
# 5                                          no_text
# 6                                          no_text
# 7                                          no_text
# 8                                          no_text
# 9                                          no_text
# 10                                         no_text
# 11                                         no_text
# 12                          position control pools
# 13                                         no_text
# 14                                         no_text
# 15                              all campus payroll
# 16                                         no_text
# 17                                         no_text
# 18                                         no_text
# 19                                         no_text
# 20                                         no_text
# 21                                         no_text
# 22                                         no_text
# 23                                         no_text
# 24                                         no_text
# 25                                         no_text
# 26                                         no_text
# 27                                         no_text
# 28                                         no_text
# 29                       transportation department
# ...                                            ...
# 400247                                     no_text
# 400248  new construction department administration
# 400249                                     no_text
# 400250                                     no_text
# 400251                                     no_text
# 400252                              teacher supply
# 400253                                     no_text
# 400254                                     no_text
# 400255                                     no_text
# 400256                                     no_text
# 400257                                  vocational
# 400258                                     no_text
# 400259                                     no_text
# 400260                                     no_text
# 400261                                     no_text
# 400262                                     no_text
# 400263                                     no_text
# 400264                                     no_text
# 400265                   transportation department
# 400266                                     no_text
# 400267                                     no_text
# 400268                                     no_text
# 400269                             child nutrition
# 400270                                     no_text
# 400271                                     no_text
# 400272                                     no_text
# 400273                                     no_text
# 400274                                     no_text
# 400275                                     no_text
# 400276                  instruction and curriculum
#
#                                      Function_Description  \
# 0                                                 no_text
# 1                                                 rgn gob
# 2                                                 no_text
# 3                                 unalloc budgets schools
# 4                                             non project
# 5                                             non project
# 6                                                 no_text
# 7                                             non project
# 8                             ela s teaching spanish only
# 9                                 unalloc budgets schools
# 10       state and federal projects coordination services
# 11                                            instruction
# 12                                                no_text
# 13                                    disadvantaged youth
# 14                                        basic fefp k 12
# 15                                            instruction
# 16                                        basic fefp k 12
# 17                                      security services
# 18                                            non project
# 19        instruction and curriculum development services
# 20                   direction of support services pupils
# 21                                unalloc budgets schools
# 22                                    disadvantaged youth
# 23                                      guidance services
# 24                                                no_text
# 25                                                no_text
# 26        instruction and curriculum development services
# 27                                           core matters
# 28                           ela e teaching sheltered eng
# 29                                         transportation
# ...                                                   ...
# 400247                             psychological services
# 400248            facilities acquisition and construction
# 400249                            unalloc budgets schools
# 400250                            special ed severe needs
# 400251                        ela s teaching spanish only
# 400252                                            no_text
# 400253                                      title iii ela
# 400254                        read to achieve round three
# 400255                                            title i
# 400256                                        non project
# 400257  curriculum development and instructional staff...
# 400258                                    basic fefp k 12
# 400259                                     staff services
# 400260                                            no_text
# 400261                                            no_text
# 400262                     title ii part a teacher qualit
# 400263                       ela e teaching sheltered eng
# 400264    instruction and curriculum development services
# 400265                                     transportation
# 400266                                        instruction
# 400267                                             ns gob
# 400268                                            no_text
# 400269            food services child nutrition fund only
# 400270         other improvements of instruction services
# 400271                     title ii part a teacher qualit
# 400272                           inst staff training svcs
# 400273                                         title ii d
# 400274                                            no_text
# 400275                                        non project
# 400276                                        instruction
#
#                                          Fund_Description  \
# 0                                            general fund
# 1                                                 no_text
# 2                                  general purpose school
# 3                                                 no_text
# 4                                                 no_text
# 5                                                 no_text
# 6                                              local fund
# 7                                                 no_text
# 8                                                 no_text
# 9                                                 no_text
# 10                                         school to work
# 11                                           general fund
# 12                                 general purpose school
# 13      title i disadvantaged children targeted assist...
# 14                             conversion charter schools
# 15                                 general operating fund
# 16                                           general fund
# 17                                                general
# 18                                                no_text
# 19                                          special trust
# 20                                          special trust
# 21                                                no_text
# 22      title i disadvantaged children targeted assist...
# 23                             conversion charter schools
# 24                                 general purpose school
# 25                                school federal projects
# 26                                          special trust
# 27                                                no_text
# 28                                                no_text
# 29                                 general operating fund
# ...                                                   ...
# 400247                                            general
# 400248                             general operating fund
# 400249                                            no_text
# 400250                                            no_text
# 400251                                            no_text
# 400252                            school federal projects
# 400253                                            no_text
# 400254                                            no_text
# 400255                                            no_text
# 400256                                            no_text
# 400257                             general operating fund
# 400258                         conversion charter schools
# 400259                       extended learning center elc
# 400260                            school federal projects
# 400261                             general purpose school
# 400262                                            no_text
# 400263                                            no_text
# 400264                                      special trust
# 400265                             general operating fund
# 400266                                       general fund
# 400267                                            no_text
# 400268                             general purpose school
# 400269        national school breakfast and lunch program
# 400270                         miscellaneous state grants
# 400271                                            no_text
# 400272                                       general fund
# 400273                                            no_text
# 400274                                 schoolwide schools
# 400275                                            no_text
# 400276              title part a improving basic programs
#
#                        Job_Title_Description            Location_Description  \
# 0                         teacher elementary                         no_text
# 1                                      blank                         no_text
# 2                            tcher 2nd grade                         no_text
# 3                     teacher short term sub                         no_text
# 4                     teacher secondary high                         no_text
# 5                          custodian pt jobs                         no_text
# 6                                    no_text                         no_text
# 7                   sub manager food service  district wide organization uni
# 8                         teacher elementary                         no_text
# 9                teacher retrd shrt term sub                         no_text
# 10                                   no_text                         no_text
# 11                                   no_text                         no_text
# 12      tcher p e elem position control pool                         no_text
# 13                                   no_text                         no_text
# 14                           sub teacher all                         charter
# 15                   teacher substitute pool                          school
# 16                      teacher title i elem                          school
# 17                admin lieutenant comm serv    safety and security division
# 18                                     blank                         no_text
# 19                                   no_text                         no_text
# 20                                   no_text                         no_text
# 21                    teacher short term sub                         no_text
# 22                        tchr scndy english      sr oth certificated person
# 23                 ese clerical assistant ii                         charter
# 24                                   no_text                         no_text
# 25                   tcher english secondary                         no_text
# 26                                   no_text                         no_text
# 27                    teacher short term sub                         no_text
# 28                        teacher elementary                         no_text
# 29            transportation bus drivers reg                   undistributed
# ...                                      ...                             ...
# 400247                          psychologist      psychological services off
# 400248            clerical bldg construction                     unallocated
# 400249                 teacher super sub d d       all schools undistributed
# 400250            teacher spec ed center prg                         no_text
# 400251                    teacher elementary                         no_text
# 400252                               no_text                         no_text
# 400253                ela general assignment                         no_text
# 400254                    teacher elementary                         no_text
# 400255                ela general assignment                         no_text
# 400256                    teacher elementary                         no_text
# 400257                               no_text                          school
# 400258            teacher soc studies middle                          school
# 400259                               no_text                          school
# 400260                               no_text                         no_text
# 400261               assistant principal sec                         no_text
# 400262                    teacher elementary                    math science
# 400263                    teacher elementary                         no_text
# 400264                               no_text                         no_text
# 400265         transportation substitute reg                     unallocated
# 400266                               no_text                         no_text
# 400267                secondary spec ed para                         no_text
# 400268                               no_text                         no_text
# 400269          cafeteria employee food serv                          school
# 400270                               no_text                         no_text
# 400271                    teacher elementary                    math science
# 400272           curriculum resource teacher       staff dev and instr media
# 400273           teacher retrd shrt term sub                         no_text
# 400274                        school liaison                         no_text
# 400275                 library technician ii            ed resource services
# 400276               teacher substitute pool                          school
#
#                                        Object_Description  \
# 0                                                 no_text
# 1                                     contractor services
# 2                              personal services teachers
# 3                                       employee benefits
# 4                            teacher coverage for teacher
# 5                                         contra benefits
# 6                                             educational
# 7                                       employee benefits
# 8                                       employee benefits
# 9                                       employee benefits
# 10                                              equipment
# 11                                               supplies
# 12                             personal services teachers
# 13                                                regular
# 14                                other personal services
# 15        salaries and wages for substitute professionals
# 16                                               supplies
# 17                                                regular
# 18                                            electricity
# 19                  non certificated travel reimbursement
# 20                                     purchased services
# 21                         salaries of part time employee
# 22                                                regular
# 23                                                bonuses
# 24        personal services substitute teachers certified
# 25                             personal services teachers
# 26                                              equipment
# 27                                      employee benefits
# 28                                      employee benefits
# 29          extra duty pay overtime for support personnel
# ...                                                   ...
# 400247                                            regular
# 400248      extra duty pay overtime for support personnel
# 400249                     salaries of part time employee
# 400250                      salaries of regular employees
# 400251                      salaries of regular employees
# 400252  personal services substitute teachers non cert...
# 400253                                  employee benefits
# 400254                       employer pd med contribution
# 400255                     salaries of part time employee
# 400256                                    contra benefits
# 400257               travel and subsistence employee only
# 400258                                  classroom teacher
# 400259                                   in county travel
# 400260    personal services substitute teachers certified
# 400261             personal services assistant principals
# 400262                     additional extra duty pay stip
# 400263                      salaries of regular employees
# 400264                other pupil transportation services
# 400265      extra duty pay overtime for support personnel
# 400266                                           supplies
# 400267                     additional extra duty pay stip
# 400268    personal services substitute teachers certified
# 400269            salaries or wages for support personnel
# 400270                            other awards and prizes
# 400271                     additional extra duty pay stip
# 400272                               workshop participant
# 400273                     salaries of part time employee
# 400274                                            no_text
# 400275                                  employee benefits
# 400276    salaries and wages for substitute professionals
#
#                        Position_Extra  \
# 0                        kindergarten
# 1                        undesignated
# 2                             teacher
# 3          professional instructional
# 4          professional instructional
# 5                        undesignated
# 6              supplies and materials
# 7                        undesignated
# 8          professional instructional
# 9          professional instructional
# 10                            no_text
# 11                            no_text
# 12                            teacher
# 13                            no_text
# 14                            no_text
# 15                 degreed substitute
# 16                            no_text
# 17                            no_text
# 18                       undesignated
# 19                            no_text
# 20                            no_text
# 21         professional instructional
# 22                            no_text
# 23                            no_text
# 24                 substitute teacher
# 25                       teacher days
# 26                            no_text
# 27         professional instructional
# 28         professional instructional
# 29                         bus driver
# ...                               ...
# 400247                        no_text
# 400248         dir exec dir secretary
# 400249     professional instructional
# 400250     professional instructional
# 400251     professional instructional
# 400252             substitute teacher
# 400253               paraprofessional
# 400254     professional instructional
# 400255               paraprofessional
# 400256                   undesignated
# 400257                        no_text
# 400258                        no_text
# 400259                        no_text
# 400260             substitute teacher
# 400261                 asst principal
# 400262     professional instructional
# 400263     professional instructional
# 400264                        no_text
# 400265       radio substitute drivers
# 400266                        no_text
# 400267               paraprofessional
# 400268             substitute teacher
# 400269        reg food service worker
# 400270                        no_text
# 400271     professional instructional
# 400272                        no_text
# 400273     professional instructional
# 400274                 parent title i
# 400275  office administrative support
# 400276           certified substitute
#
#                                       Program_Description  \
# 0                                            kindergarten
# 1                           building improvement services
# 2                                     instruction regular
# 3                          general middle junior high sch
# 4                           general high school education
# 5                                       employee benefits
# 6                                 special education local
# 7                                            undesignated
# 8                            general elementary education
# 9                            general elementary education
# 10                                                no_text
# 11                                 primary grades program
# 12                                    instruction regular
# 13                                                no_text
# 14                                                no_text
# 15      bilingual education and special language programs
# 16                                                no_text
# 17                                                no_text
# 18                           care upkeep of bldg services
# 19                                                no_text
# 20                                                no_text
# 21                           general elementary education
# 22                                                no_text
# 23                                                no_text
# 24                                    instruction regular
# 25                                    instruction regular
# 26                                                no_text
# 27                           instructional staff training
# 28                           general elementary education
# 29                                          undistributed
# ...                                                   ...
# 400247                                            no_text
# 400248                                      undistributed
# 400249                            other general education
# 400250                         special education tmd high
# 400251                       general elementary education
# 400252                                   instruction sped
# 400253                      general high school education
# 400254                       general elementary education
# 400255                       general elementary education
# 400256                                  employee benefits
# 400257                              career and technology
# 400258                                            no_text
# 400259                                            no_text
# 400260                        support regular instruction
# 400261                                 principal s office
# 400262                       instructional staff training
# 400263                       general elementary education
# 400264                                            no_text
# 400265                                      undistributed
# 400266                             primary grades program
# 400267                     general middle junior high sch
# 400268                                instruction regular
# 400269                                      undistributed
# 400270                                            no_text
# 400271                       instructional staff training
# 400272                                            no_text
# 400273                       instructional staff training
# 400274                                               misc
# 400275                             media support services
# 400276                              accelerated education
#
#                                 SubFund_Description  \
# 0                                           no_text
# 1                                     building fund
# 2                                           no_text
# 3                                      general fund
# 4                                      general fund
# 5                                      general fund
# 6                                             local
# 7                                      general fund
# 8                                      general fund
# 9                                      general fund
# 10                  support services administration
# 11                           primary grades program
# 12                                          no_text
# 13                              special instruction
# 14                                          no_text
# 15                                       operations
# 16                                          no_text
# 17      operation and maintenance of plant services
# 18                                     general fund
# 19             support services instructional staff
# 20                          support services pupils
# 21                                     general fund
# 22                              special instruction
# 23                                          no_text
# 24                                          no_text
# 25                                          no_text
# 26             support services instructional staff
# 27                                     general fund
# 28                                     general fund
# 29                                       operations
# ...                                             ...
# 400247                      support services pupils
# 400248                                   operations
# 400249                                 general fund
# 400250                                 general fund
# 400251                                 general fund
# 400252                                      no_text
# 400253                         federal gdpg fund fy
# 400254                    state and local gdpg fund
# 400255                         federal gdpg fund fy
# 400256                                 general fund
# 400257                                      no_text
# 400258                                      no_text
# 400259                                      no_text
# 400260                                      no_text
# 400261                                      no_text
# 400262                         federal gdpg fund fy
# 400263                                 general fund
# 400264         support services instructional staff
# 400265                                   operations
# 400266                       primary grades program
# 400267                                         bond
# 400268                                      no_text
# 400269                              child nutrition
# 400270         support services instructional staff
# 400271                         federal gdpg fund fy
# 400272                                      no_text
# 400273                         federal gdpg fund fy
# 400274                                      no_text
# 400275                                levy override
# 400276        title part a improving basic programs
#
#                                Sub_Object_Description  \
# 0                                             no_text
# 1                                             no_text
# 2                                             no_text
# 3                                             no_text
# 4                                             no_text
# 5                                             no_text
# 6                                             no_text
# 7                                             no_text
# 8                                             no_text
# 9                                             no_text
# 10                                          equipment
# 11                                            no_text
# 12                                            no_text
# 13          certificated employees salaries and wages
# 14                                            no_text
# 15         salaries and wages for substitute teachers
# 16                                            no_text
# 17                                            no_text
# 18                                            no_text
# 19                     travel mileage meeting expense
# 20                                 purchased services
# 21                                            no_text
# 22          certificated employees salaries and wages
# 23                                            no_text
# 24                                            no_text
# 25                                            no_text
# 26                                          equipment
# 27                                            no_text
# 28                                            no_text
# 29      extra duty pay overtime for support personnel
# ...                                               ...
# 400247      certificated employees salaries and wages
# 400248  extra duty pay overtime for support personnel
# 400249                                        no_text
# 400250                                        no_text
# 400251                                        no_text
# 400252                                        no_text
# 400253                                        no_text
# 400254                                        no_text
# 400255                                        no_text
# 400256                                        no_text
# 400257           travel and subsistence employee only
# 400258                                        no_text
# 400259                                        no_text
# 400260                                        no_text
# 400261                                        no_text
# 400262                                        no_text
# 400263                                        no_text
# 400264                           pupil transportation
# 400265  extra duty pay overtime for support personnel
# 400266                                        no_text
# 400267                                        no_text
# 400268                                        no_text
# 400269        salaries or wages for support personnel
# 400270                              awards and prizes
# 400271                                        no_text
# 400272                                        no_text
# 400273                                        no_text
# 400274                                        no_text
# 400275                                        no_text
# 400276     inservice substitute teachers grant funded
#
#                                           Text_1  \
# 0                                        no_text
# 1                  building improvement services
# 2                                        no_text
# 3                            regular instruction
# 4                            regular instruction
# 5                              employee benefits
# 6                                        no_text
# 7                                   undesignated
# 8                            regular instruction
# 9                            regular instruction
# 10                       itemai city yth emp opp
# 11                                       no_text
# 12                                       no_text
# 13                                       title i
# 14                                       no_text
# 15                                   regular pay
# 16                                  teacher lead
# 17                               safety security
# 18                  operation and maint of plant
# 19                          resp sexual behavior
# 20                           home team marketing
# 21                           regular instruction
# 22                          building allocations
# 23                                       no_text
# 24                                       no_text
# 25                    esea title i disadvantaged
# 26                     key bank national associa
# 27                           instructional staff
# 28                           regular instruction
# 29                 addl regular pay not smoothed
# ...                                          ...
# 400247                    psychological services
# 400248                                  overtime
# 400249                       regular instruction
# 400250                         special education
# 400251                       regular instruction
# 400252  individuals with disabilities act part b
# 400253                       regular instruction
# 400254                       regular instruction
# 400255                       regular instruction
# 400256                         employee benefits
# 400257                                   no_text
# 400258                                   no_text
# 400259                                   no_text
# 400260                                     other
# 400261                                   no_text
# 400262                       instructional staff
# 400263                       regular instruction
# 400264                     items foundation june
# 400265                                  overtime
# 400266                                   no_text
# 400267                       regular instruction
# 400268                                   no_text
# 400269                               regular pay
# 400270                  school improv incentives
# 400271                       instructional staff
# 400272                 staff dev and instr media
# 400273                       instructional staff
# 400274                                   no_text
# 400275                       instructional staff
# 400276                             miscellaneous
#
#                                Text_2       Text_3  \
# 0                             no_text      no_text
# 1                   bond expenditures      regular
# 2                             no_text      no_text
# 3                        teacher subs      regular
# 4                        teacher subs  alternative
# 5                             no_text      no_text
# 6       special education instruction      no_text
# 7                             no_text      no_text
# 8                             no_text      regular
# 9                        teacher subs      regular
# 10                            no_text      no_text
# 11                            no_text      no_text
# 12                            no_text      no_text
# 13                            no_text      no_text
# 14                            no_text      no_text
# 15                            no_text      no_text
# 16                            no_text      no_text
# 17                           adm prof      no_text
# 18               operations utilities      regular
# 19                            no_text      no_text
# 20                            no_text      no_text
# 21                       teacher subs      regular
# 22                            teacher      no_text
# 23                            no_text      no_text
# 24                            no_text      no_text
# 25                            no_text      no_text
# 26                            no_text      no_text
# 27                            no_text      regular
# 28                            no_text      regular
# 29                            no_text      no_text
# ...                               ...          ...
# 400247                     teachersup      no_text
# 400248                        no_text      no_text
# 400249                   teacher subs      no_text
# 400250            severe disabilities      regular
# 400251                        no_text      regular
# 400252                        no_text      no_text
# 400253                        no_text      regular
# 400254                        no_text      regular
# 400255                        no_text      regular
# 400256                        no_text      no_text
# 400257                        no_text      no_text
# 400258                        no_text      no_text
# 400259                        no_text      no_text
# 400260                        no_text      no_text
# 400261                        no_text      no_text
# 400262                   math science      no_text
# 400263                        no_text      regular
# 400264                        no_text      no_text
# 400265                        no_text      no_text
# 400266                        no_text      no_text
# 400267                        no_text   turnaround
# 400268                        no_text      no_text
# 400269                        no_text      no_text
# 400270                        no_text      no_text
# 400271                   math science      no_text
# 400272                        no_text      no_text
# 400273                        no_text      regular
# 400274                        no_text      no_text
# 400275  educational resource services      no_text
# 400276                        no_text      no_text
#
#                                     Text_4
# 0                                  no_text
# 1                                  no_text
# 2                      regular instruction
# 3                                  no_text
# 4                                  no_text
# 5                                  no_text
# 6                                  no_text
# 7                                  no_text
# 8                                  no_text
# 9                                  no_text
# 10                                 no_text
# 11                                 no_text
# 12                     regular instruction
# 13                                 no_text
# 14                                 no_text
# 15                                 no_text
# 16                                 no_text
# 17                                 no_text
# 18                                 no_text
# 19                                 no_text
# 20                                 no_text
# 21                                 no_text
# 22                                 no_text
# 23                                 no_text
# 24                     regular instruction
# 25                                sig arra
# 26                                 no_text
# 27                                 no_text
# 28                                 no_text
# 29              transportation bus drivers
# ...                                    ...
# 400247                             no_text
# 400248                             no_text
# 400249                             no_text
# 400250                             no_text
# 400251                             no_text
# 400252                         idea part b
# 400253                             no_text
# 400254                             no_text
# 400255                             no_text
# 400256                             no_text
# 400257                             no_text
# 400258                             no_text
# 400259                             no_text
# 400260                     state tif grant
# 400261                 office of principal
# 400262                             no_text
# 400263                             no_text
# 400264                             no_text
# 400265          transportation second runs
# 400266                             no_text
# 400267                             no_text
# 400268                 regular instruction
# 400269                       undistributed
# 400270                             no_text
# 400271                             no_text
# 400272                             no_text
# 400273                             no_text
# 400274                             no_text
# 400275                             no_text
# 400276  multilingual dist prof development
#
# [400277 rows x 14 columns]
#            Facility_or_Department  \
# 0                         no_text
# 1                         no_text
# 2                         no_text
# 3                         no_text
# 4                         no_text
# 5                         no_text
# 6                         no_text
# 7                         no_text
# 8                         no_text
# 9                         no_text
# 10                        no_text
# 11                        no_text
# 12                        no_text
# 13                        no_text
# 14                        no_text
# 15                        no_text
# 16                        no_text
# 17                        no_text
# 18                        no_text
# 19                        no_text
# 20                        no_text
# 21                        no_text
# 22                        no_text
# 23                        no_text
# 24                        no_text
# 25                        no_text
# 26                        no_text
# 27                        no_text
# 28                        no_text
# 29                        no_text
# ...                           ...
# 50034  instruction and curriculum
# 50035                 warehousing
# 50036          all campus payroll
# 50037          all campus payroll
# 50038          all campus payroll
# 50039  instruction and curriculum
# 50040                     no_text
# 50041          all campus payroll
# 50042          all campus payroll
# 50043          all campus payroll
# 50044  instruction and curriculum
# 50045          all campus payroll
# 50046                     no_text
# 50047  instruction and curriculum
# 50048         gifted and talented
# 50049          all campus payroll
# 50050  instruction and curriculum
# 50051  instruction and curriculum
# 50052  instruction and curriculum
# 50053   transportation department
# 50054        custodial department
# 50055         textbook department
# 50056             child nutrition
# 50057        custodial department
# 50058                     no_text
# 50059                     no_text
# 50060                     no_text
# 50061                     no_text
# 50062                     no_text
# 50063                     no_text
#
#                               Function_Description  \
# 0                                      instruction
# 1         cocurricular extra curricular activities
# 2                                      instruction
# 3                                      instruction
# 4                                school leadership
# 5                                school leadership
# 6                           student transportation
# 7      guidance counseling and evaluation services
# 8                                      instruction
# 9                                    food services
# 10                                     instruction
# 11                                     instruction
# 12      curriculum instructional staff development
# 13                                     instruction
# 14                                     instruction
# 15                                     instruction
# 16                                     instruction
# 17                              community services
# 18                        instructional leadership
# 19                   security monitoring servicess
# 20        cocurricular extra curricular activities
# 21                                     instruction
# 22                                     instruction
# 23                                     instruction
# 24                        data processing services
# 25                               school leadership
# 26                                     instruction
# 27        cocurricular extra curricular activities
# 28      curriculum instructional staff development
# 29                                     instruction
# ...                                            ...
# 50034                                  instruction
# 50035        facilities maintenance and operations
# 50036                                  instruction
# 50037                                  instruction
# 50038                                  instruction
# 50039                                  instruction
# 50040                   extracurricular activities
# 50041                                  instruction
# 50042                                  instruction
# 50043                                  instruction
# 50044                                  instruction
# 50045                                  instruction
# 50046                                  instruction
# 50047                                  instruction
# 50048                   extracurricular activities
# 50049                   extracurricular activities
# 50050                                  instruction
# 50051  guidance counseling and evaluation services
# 50052                                  instruction
# 50053                               transportation
# 50054        facilities maintenance and operations
# 50055        facilities maintenance and operations
# 50056      food services child nutrition fund only
# 50057        facilities maintenance and operations
# 50058                            school leadership
# 50059                                      no_text
# 50060                                      no_text
# 50061                                      no_text
# 50062                                      no_text
# 50063                                      no_text
#
# ...
# 20                                 athletics and related
# 21                                     special education
# 22                                   bilingual education
# 23                                 career and technology
# 24                                         undistributed
# 25                                         undistributed
# 26                       disciplinary aep basic services
# 27                                 athletics and related
# 28                                 accelerated education
# 29                            basic educational services
# ...                                                  ...
# 50034  title i part a schoolwide activities related t...
# 50035                                      undistributed
# 50036                         basic educational services
# 50037                                              pre k
# 50038  bilingual education and special language programs
# 50039                         basic educational services
# 50040                                      undistributed
# 50041                         basic educational services
# 50042  services to students with disabilities special...
# 50043                         basic educational services
# 50044  title i part a schoolwide activities related t...
# 50045                         basic educational services
# 50046                         basic educational services
# 50047  title i part a schoolwide activities related t...
# 50048                                gifted and talented
# 50049                                      undistributed
# 50050  title i part a schoolwide activities related t...
# 50051                                              pre k
# 50052  title i part a schoolwide activities related t...
# 50053                                      undistributed
# 50054                                      undistributed
# 50055                                      undistributed
# 50056                                      undistributed
# 50057                                      undistributed
# 50058                                      undistributed
# 50059                                             nurses
# 50060                                             nurses
# 50061                                             nurses
# 50062                                             nurses
# 50063                                             nurses
#
#                          SubFund_Description  \
# 0                                    no_text
# 1                                    no_text
# 2                                    no_text
# 3                                    no_text
# 4                                    no_text
# 5                                    no_text
# 6                                    no_text
# 7                                    no_text
# 8                                    no_text
# 9                                    no_text
# 10                                   no_text
# 11                                   no_text
# 12                                   no_text
# 13                                   no_text
# 14                                   no_text
# 15                                   no_text
# 16                                   no_text
# 17                                   no_text
# 18                                   no_text
# 19                                   no_text
# 20                                   no_text
# 21                                   no_text
# 22                                   no_text
# 23                                   no_text
# 24                                   no_text
# 25                                   no_text
# 26                                   no_text
# 27                                   no_text
# 28                                   no_text
# 29                                   no_text
# ...                                      ...
# 50034  title part a improving basic programs
# 50035                             operations
# 50036                             operations
# 50037                             operations
# 50038                             operations
# 50039       student success initiative grant
# 50040                                no_text
# 50041                             operations
# 50042                             operations
# 50043                             operations
# 50044               title school improvement
# 50045                             operations
# 50046                             elementary
# 50047  title part a improving basic programs
# 50048                                no_text
# 50049                             operations
# 50050                                no_text
# 50051                                no_text
# 50052  title part a improving basic programs
# 50053                             operations
# 50054                             operations
# 50055                             operations
# 50056                        child nutrition
# 50057                                no_text
# 50058                                no_text
# 50059                                no_text
# 50060                                no_text
# 50061                                no_text
# 50062                                no_text
# 50063                                no_text
#
#                                   Sub_Object_Description  \
# 0               line item that is paid with campus money
# 1                                                general
# 2                                                general
# 3                                                general
# 4                                                general
# 5                                          magnet school
# 6                                                general
# 7                                                general
# 8                                                    art
# 9                                                general
# 10                                               general
# 11                                               general
# 12              line item that is paid with campus money
# 13                                               general
# 14                                               general
# 15                                               general
# 16                                               general
# 17                                               general
# 18                                               general
# 19              line item that is paid with campus money
# 20                                               general
# 21                                               general
# 22                                               general
# 23                                               general
# 24                                               general
# 25                                               general
# 26                                         language arts
# 27                                           boys tennis
# 28                                         solution team
# 29                                               general
# ...                                                  ...
# 50034                                      extended year
# 50035      extra duty pay overtime for support personnel
# 50036  salaries and wages for teachers and other prof...
# 50037            salaries or wages for support personnel
# 50038         salaries and wages for substitute teachers
# 50039                                      extended week
# 50040                      miscellaneous operating costs
# 50041  salaries and wages for teachers and other prof...
# 50042                           critical needs incentive
# 50043  salaries and wages for teachers and other prof...
# 50044                                       extended day
# 50045  salaries and wages for teachers and other prof...
# 50046      extra duty pay overtime for support personnel
# 50047                                      extended week
# 50048                                   general supplies
# 50049                               incentive supplement
# 50050                                   general supplies
# 50051                                 teacher retirement
# 50052                                           tutoring
# 50053      extra duty pay overtime for support personnel
# 50054      extra duty pay overtime for support personnel
# 50055              temporary part time support personnel
# 50056            salaries or wages for support personnel
# 50057    contracted maintenance and repair buildings and
# 50058                                   food hospitality
# 50059                                            no_text
# 50060                                            no_text
# 50061                                            no_text
# 50062                                            no_text
# 50063                                            no_text
#
#                           Text_1   Text_2   Text_3  \
# 0                        no_text  no_text  no_text
# 1                        no_text  no_text  no_text
# 2                        no_text  no_text  no_text
# 3                        no_text  no_text  no_text
# 4                        no_text  no_text  no_text
# 5                        no_text  no_text  no_text
# 6                        no_text  no_text  no_text
# 7                        no_text  no_text  no_text
# 8                        no_text  no_text  no_text
# 9                        no_text  no_text  no_text
# 10                       no_text  no_text  no_text
# 11                       no_text  no_text  no_text
# 12                       no_text  no_text  no_text
# 13                       no_text  no_text  no_text
# 14                       no_text  no_text  no_text
# 15                       no_text  no_text  no_text
# 16                       no_text  no_text  no_text
# 17                       no_text  no_text  no_text
# 18                       no_text  no_text  no_text
# 19                       no_text  no_text  no_text
# 20                       no_text  no_text  no_text
# 21                       no_text  no_text  no_text
# 22                       no_text  no_text  no_text
# 23                       no_text  no_text  no_text
# 24                       no_text  no_text  no_text
# 25                       no_text  no_text  no_text
# 26                       no_text  no_text  no_text
# 27                       no_text  no_text  no_text
# 28                       no_text  no_text  no_text
# 29                       no_text  no_text  no_text
# ...                          ...      ...      ...
# 50034              extended year  no_text  no_text
# 50035                   overtime  no_text  no_text
# 50036                regular pay  no_text  no_text
# 50037                regular pay  no_text  no_text
# 50038                regular pay  no_text  no_text
# 50039              miscellaneous  no_text  no_text
# 50040                    no_text  no_text  no_text
# 50041                regular pay  no_text  no_text
# 50042  critical needs supplement  no_text  no_text
# 50043                regular pay  no_text  no_text
# 50044              miscellaneous  no_text  no_text
# 50045                regular pay  no_text  no_text
# 50046              extended days  no_text  no_text
# 50047              extended days  no_text  no_text
# 50048                    no_text  no_text  no_text
# 50049            preformance pay  no_text  no_text
# 50050                    no_text  no_text  no_text
# 50051                    no_text  no_text  no_text
# 50052              extended days  no_text  no_text
# 50053                  extra run  no_text  no_text
# 50054                   overtime  no_text  no_text
# 50055                regular pay  no_text  no_text
# 50056                regular pay  no_text  no_text
# 50057                    no_text  no_text  no_text
# 50058                    no_text  no_text  no_text
# 50059                    no_text  no_text  no_text
# 50060                    no_text  no_text  no_text
# 50061                    no_text  no_text  no_text
# 50062                    no_text  no_text  no_text
# 50063                    no_text  no_text  no_text
#
#                                               Text_4
# 0                                            no_text
# 1                                            no_text
# 2                                            no_text
# 3                                            no_text
# 4                                            no_text
# 5                                            no_text
# 6                                            no_text
# 7                                            no_text
# 8                                            no_text
# 9                                            no_text
# 10                                           no_text
# 11                                           no_text
# 12                                           no_text
# 13                                           no_text
# 14                                           no_text
# 15                                           no_text
# 16                                           no_text
# 17                                           no_text
# 18                                           no_text
# 19                                           no_text
# 20                                           no_text
# 21                                           no_text
# 22                                           no_text
# 23                                           no_text
# 24                                           no_text
# 25                                           no_text
# 26                                           no_text
# 27                                           no_text
# 28                                           no_text
# 29                                           no_text
# ...                                              ...
# 50034                                        no_text
# 50035                                        no_text
# 50036  basic educational services district objective
# 50037                                        no_text
# 50038                                        no_text
# 50039  basic educational services district objective
# 50040                                        no_text
# 50041  basic educational services district objective
# 50042                                        no_text
# 50043  basic educational services district objective
# 50044                                        no_text
# 50045  basic educational services district objective
# 50046                                        no_text
# 50047                                        no_text
# 50048                                        no_text
# 50049                                  undistributed
# 50050                                        no_text
# 50051                                     extra duty
# 50052                                        no_text
# 50053                     transportation second runs
# 50054                                        no_text
# 50055                                        no_text
# 50056                                  undistributed
# 50057                                        no_text
# 50058                                        no_text
# 50059                                        no_text
# 50060                                        no_text
# 50061                                        no_text
# 50062                                        no_text
# 50063                                        no_text
#
# [50064 rows x 14 columns]

# %%
#combine all column of the dataset
training_data["combined"] = [' '.join(row) for row in training_data[training_data.columns].values]
test_data["combined"] = [' '.join(row) for row in test_data[test_data.columns].values]

# %%
#combined colums of tets and train dataset
print(training_data)
print(test_data)
# Out:
#                             Facility_or_Department  \
# 0                                          no_text
# 1                                          no_text
# 2                                          no_text
# 3                                          no_text
# 4                                          no_text
# 5                                          no_text
# 6                                          no_text
# 7                                          no_text
# 8                                          no_text
# 9                                          no_text
# 10                                         no_text
# 11                                         no_text
# 12                          position control pools
# 13                                         no_text
# 14                                         no_text
# 15                              all campus payroll
# 16                                         no_text
# 17                                         no_text
# 18                                         no_text
# 19                                         no_text
# 20                                         no_text
# 21                                         no_text
# 22                                         no_text
# 23                                         no_text
# 24                                         no_text
# 25                                         no_text
# 26                                         no_text
# 27                                         no_text
# 28                                         no_text
# 29                       transportation department
# ...                                            ...
# 400247                                     no_text
# 400248  new construction department administration
# 400249                                     no_text
# 400250                                     no_text
# 400251                                     no_text
# 400252                              teacher supply
# 400253                                     no_text
# 400254                                     no_text
# 400255                                     no_text
# 400256                                     no_text
# 400257                                  vocational
# 400258                                     no_text
# 400259                                     no_text
# 400260                                     no_text
# 400261                                     no_text
# 400262                                     no_text
# 400263                                     no_text
# 400264                                     no_text
# 400265                   transportation department
# 400266                                     no_text
# 400267                                     no_text
# 400268                                     no_text
# 400269                             child nutrition
# 400270                                     no_text
# 400271                                     no_text
# 400272                                     no_text
# 400273                                     no_text
# 400274                                     no_text
# 400275                                     no_text
# 400276                  instruction and curriculum
#
#                                      Function_Description  \
# 0                                                 no_text
# 1                                                 rgn gob
# 2                                                 no_text
# 3                                 unalloc budgets schools
# 4                                             non project
# 5                                             non project
# 6                                                 no_text
# 7                                             non project
# 8                             ela s teaching spanish only
# 9                                 unalloc budgets schools
# 10       state and federal projects coordination services
# 11                                            instruction
# 12                                                no_text
# 13                                    disadvantaged youth
# 14                                        basic fefp k 12
# 15                                            instruction
# 16                                        basic fefp k 12
# 17                                      security services
# 18                                            non project
# 19        instruction and curriculum development services
# 20                   direction of support services pupils
# 21                                unalloc budgets schools
# 22                                    disadvantaged youth
# 23                                      guidance services
# 24                                                no_text
# 25                                                no_text
# 26        instruction and curriculum development services
# 27                                           core matters
# 28                           ela e teaching sheltered eng
# 29                                         transportation
# ...                                                   ...
# 400247                             psychological services
# 400248            facilities acquisition and construction
# 400249                            unalloc budgets schools
# 400250                            special ed severe needs
# 400251                        ela s teaching spanish only
# 400252                                            no_text
# 400253                                      title iii ela
# 400254                        read to achieve round three
# 400255                                            title i
# 400256                                        non project
# 400257  curriculum development and instructional staff...
# 400258                                    basic fefp k 12
# 400259                                     staff services
# 400260                                            no_text
# 400261                                            no_text
# 400262                     title ii part a teacher qualit
# 400263                       ela e teaching sheltered eng
# 400264    instruction and curriculum development services
# 400265                                     transportation
# 400266                                        instruction
# 400267                                             ns gob
# 400268                                            no_text
# 400269            food services child nutrition fund only
# 400270         other improvements of instruction services
# 400271                     title ii part a teacher qualit
# 400272                           inst staff training svcs
# 400273                                         title ii d
# 400274                                            no_text
# 400275                                        non project
# 400276                                        instruction
#
#                                          Fund_Description  \
# 0                                            general fund
# 1                                                 no_text
# 2                                  general purpose school
# 3                                                 no_text
# 4                                                 no_text
# 5                                                 no_text
# 6                                              local fund
# 7                                                 no_text
# 8                                                 no_text
# 9                                                 no_text
# 10                                         school to work
# 11                                           general fund
# 12                                 general purpose school
# 13      title i disadvantaged children targeted assist...
# 14                             conversion charter schools
# 15                                 general operating fund
# 16                                           general fund
# 17                                                general
# 18                                                no_text
# 19                                          special trust
# 20                                          special trust
# 21                                                no_text
# 22      title i disadvantaged children targeted assist...
# 23                             conversion charter schools
# 24                                 general purpose school
# 25                                school federal projects
# 26                                          special trust
# 27                                                no_text
# 28                                                no_text
# 29                                 general operating fund
# ...                                                   ...
# 400247                                            general
# 400248                             general operating fund
# 400249                                            no_text
# 400250                                            no_text
# 400251                                            no_text
# 400252                            school federal projects
# 400253                                            no_text
# 400254                                            no_text
# 400255                                            no_text
# 400256                                            no_text
# 400257                             general operating fund
# 400258                         conversion charter schools
# 400259                       extended learning center elc
# 400260                            school federal projects
# 400261                             general purpose school
# 400262                                            no_text
# 400263                                            no_text
# 400264                                      special trust
# 400265                             general operating fund
# 400266                                       general fund
# 400267                                            no_text
# 400268                             general purpose school
# 400269        national school breakfast and lunch program
# 400270                         miscellaneous state grants
# 400271                                            no_text
# 400272                                       general fund
# 400273                                            no_text
# 400274                                 schoolwide schools
# 400275                                            no_text
# 400276              title part a improving basic programs
#
#                        Job_Title_Description            Location_Description  \
# 0                         teacher elementary                         no_text
# 1                                      blank                         no_text
# 2                            tcher 2nd grade                         no_text
# 3                     teacher short term sub                         no_text
# 4                     teacher secondary high                         no_text
# 5                          custodian pt jobs                         no_text
# 6                                    no_text                         no_text
# 7                   sub manager food service  district wide organization uni
# 8                         teacher elementary                         no_text
# 9                teacher retrd shrt term sub                         no_text
# 10                                   no_text                         no_text
# 11                                   no_text                         no_text
# 12      tcher p e elem position control pool                         no_text
# 13                                   no_text                         no_text
# 14                           sub teacher all                         charter
# 15                   teacher substitute pool                          school
# 16                      teacher title i elem                          school
# 17                admin lieutenant comm serv    safety and security division
# 18                                     blank                         no_text
# 19                                   no_text                         no_text
# 20                                   no_text                         no_text
# 21                    teacher short term sub                         no_text
# 22                        tchr scndy english      sr oth certificated person
# 23                 ese clerical assistant ii                         charter
# 24                                   no_text                         no_text
# 25                   tcher english secondary                         no_text
# 26                                   no_text                         no_text
# 27                    teacher short term sub                         no_text
# 28                        teacher elementary                         no_text
# 29            transportation bus drivers reg                   undistributed
# ...                                      ...                             ...
# 400247                          psychologist      psychological services off
# 400248            clerical bldg construction                     unallocated
# 400249                 teacher super sub d d       all schools undistributed
# 400250            teacher spec ed center prg                         no_text
# 400251                    teacher elementary                         no_text
# 400252                               no_text                         no_text
# 400253                ela general assignment                         no_text
# 400254                    teacher elementary                         no_text
# 400255                ela general assignment                         no_text
# 400256                    teacher elementary                         no_text
# 400257                               no_text                          school
# 400258            teacher soc studies middle                          school
# 400259                               no_text                          school
# 400260                               no_text                         no_text
# 400261               assistant principal sec                         no_text
# 400262                    teacher elementary                    math science
# 400263                    teacher elementary                         no_text
# 400264                               no_text                         no_text
# 400265         transportation substitute reg                     unallocated
# 400266                               no_text                         no_text
# 400267                secondary spec ed para                         no_text
# 400268                               no_text                         no_text
# 400269          cafeteria employee food serv                          school
# 400270                               no_text                         no_text
# 400271                    teacher elementary                    math science
# 400272           curriculum resource teacher       staff dev and instr media
# 400273           teacher retrd shrt term sub                         no_text
# 400274                        school liaison                         no_text
# 400275                 library technician ii            ed resource services
# 400276               teacher substitute pool                          school
#
#                                        Object_Description  \
# 0                                                 no_text
# 1                                     contractor services
# 2                              personal services teachers
# 3                                       employee benefits
# 4                            teacher coverage for teacher
# 5                                         contra benefits
# 6                                             educational
# 7                                       employee benefits
# 8                                       employee benefits
# 9                                       employee benefits
# 10                                              equipment
# 11                                               supplies
# 12                             personal services teachers
# 13                                                regular
# 14                                other personal services
# 15        salaries and wages for substitute professionals
# 16                                               supplies
# 17                                                regular
# 18                                            electricity
# 19                  non certificated travel reimbursement
# 20                                     purchased services
# 21                         salaries of part time employee
# 22                                                regular
# 23                                                bonuses
# 24        personal services substitute teachers certified
# 25                             personal services teachers
# 26                                              equipment
# 27                                      employee benefits
# 28                                      employee benefits
# 29          extra duty pay overtime for support personnel
# ...                                                   ...
# 400247                                            regular
# 400248      extra duty pay overtime for support personnel
# 400249                     salaries of part time employee
# 400250                      salaries of regular employees
# 400251                      salaries of regular employees
# 400252  personal services substitute teachers non cert...
# 400253                                  employee benefits
# 400254                       employer pd med contribution
# 400255                     salaries of part time employee
# 400256                                    contra benefits
# 400257               travel and subsistence employee only
# 400258                                  classroom teacher
# 400259                                   in county travel
# 400260    personal services substitute teachers certified
# 400261             personal services assistant principals
# 400262                     additional extra duty pay stip
# 400263                      salaries of regular employees
# 400264                other pupil transportation services
# 400265      extra duty pay overtime for support personnel
# 400266                                           supplies
# 400267                     additional extra duty pay stip
# 400268    personal services substitute teachers certified
# 400269            salaries or wages for support personnel
# 400270                            other awards and prizes
# 400271                     additional extra duty pay stip
# 400272                               workshop participant
# 400273                     salaries of part time employee
# 400274                                            no_text
# 400275                                  employee benefits
# 400276    salaries and wages for substitute professionals
#
#                        Position_Extra  \
# 0                        kindergarten
# 1                        undesignated
# 2                             teacher
# 3          professional instructional
# 4          professional instructional
# 5                        undesignated
# 6              supplies and materials
# 7                        undesignated
# 8          professional instructional
# 9          professional instructional
# 10                            no_text
# 11                            no_text
# 12                            teacher
# 13                            no_text
# 14                            no_text
# 15                 degreed substitute
# 16                            no_text
# 17                            no_text
# 18                       undesignated
# 19                            no_text
# 20                            no_text
# 21         professional instructional
# 22                            no_text
# 23                            no_text
# 24                 substitute teacher
# 25                       teacher days
# 26                            no_text
# 27         professional instructional
# 28         professional instructional
# 29                         bus driver
# ...                               ...
# 400247                        no_text
# 400248         dir exec dir secretary
# 400249     professional instructional
# 400250     professional instructional
# 400251     professional instructional
# 400252             substitute teacher
# 400253               paraprofessional
# 400254     professional instructional
# 400255               paraprofessional
# 400256                   undesignated
# 400257                        no_text
# 400258                        no_text
# 400259                        no_text
# 400260             substitute teacher
# 400261                 asst principal
# 400262     professional instructional
# 400263     professional instructional
# 400264                        no_text
# 400265       radio substitute drivers
# 400266                        no_text
# 400267               paraprofessional
# 400268             substitute teacher
# 400269        reg food service worker
# 400270                        no_text
# 400271     professional instructional
# 400272                        no_text
# 400273     professional instructional
# 400274                 parent title i
# 400275  office administrative support
# 400276           certified substitute
#
#                                       Program_Description  \
# 0                                            kindergarten
# 1                           building improvement services
# 2                                     instruction regular
# 3                          general middle junior high sch
# 4                           general high school education
# 5                                       employee benefits
# 6                                 special education local
# 7                                            undesignated
# 8                            general elementary education
# 9                            general elementary education
# 10                                                no_text
# 11                                 primary grades program
# 12                                    instruction regular
# 13                                                no_text
# 14                                                no_text
# 15      bilingual education and special language programs
# 16                                                no_text
# 17                                                no_text
# 18                           care upkeep of bldg services
# 19                                                no_text
# 20                                                no_text
# 21                           general elementary education
# 22                                                no_text
# 23                                                no_text
# 24                                    instruction regular
# 25                                    instruction regular
# 26                                                no_text
# 27                           instructional staff training
# 28                           general elementary education
# 29                                          undistributed
# ...                                                   ...
# 400247                                            no_text
# 400248                                      undistributed
# 400249                            other general education
# 400250                         special education tmd high
# 400251                       general elementary education
# 400252                                   instruction sped
# 400253                      general high school education
# 400254                       general elementary education
# 400255                       general elementary education
# 400256                                  employee benefits
# 400257                              career and technology
# 400258                                            no_text
# 400259                                            no_text
# 400260                        support regular instruction
# 400261                                 principal s office
# 400262                       instructional staff training
# 400263                       general elementary education
# 400264                                            no_text
# 400265                                      undistributed
# 400266                             primary grades program
# 400267                     general middle junior high sch
# 400268                                instruction regular
# 400269                                      undistributed
# 400270                                            no_text
# 400271                       instructional staff training
# 400272                                            no_text
# 400273                       instructional staff training
# 400274                                               misc
# 400275                             media support services
# 400276                              accelerated education
#
#                                 SubFund_Description  \
# 0                                           no_text
# 1                                     building fund
# 2                                           no_text
# 3                                      general fund
# 4                                      general fund
# 5                                      general fund
# 6                                             local
# 7                                      general fund
# 8                                      general fund
# 9                                      general fund
# 10                  support services administration
# 11                           primary grades program
# 12                                          no_text
# 13                              special instruction
# 14                                          no_text
# 15                                       operations
# 16                                          no_text
# 17      operation and maintenance of plant services
# 18                                     general fund
# 19             support services instructional staff
# 20                          support services pupils
# 21                                     general fund
# 22                              special instruction
# 23                                          no_text
# 24                                          no_text
# 25                                          no_text
# 26             support services instructional staff
# 27                                     general fund
# 28                                     general fund
# 29                                       operations
# ...                                             ...
# 400247                      support services pupils
# 400248                                   operations
# 400249                                 general fund
# 400250                                 general fund
# 400251                                 general fund
# 400252                                      no_text
# 400253                         federal gdpg fund fy
# 400254                    state and local gdpg fund
# 400255                         federal gdpg fund fy
# 400256                                 general fund
# 400257                                      no_text
# 400258                                      no_text
# 400259                                      no_text
# 400260                                      no_text
# 400261                                      no_text
# 400262                         federal gdpg fund fy
# 400263                                 general fund
# 400264         support services instructional staff
# 400265                                   operations
# 400266                       primary grades program
# 400267                                         bond
# 400268                                      no_text
# 400269                              child nutrition
# 400270         support services instructional staff
# 400271                         federal gdpg fund fy
# 400272                                      no_text
# 400273                         federal gdpg fund fy
# 400274                                      no_text
# 400275                                levy override
# 400276        title part a improving basic programs
#
#                                Sub_Object_Description  \
# 0                                             no_text
# 1                                             no_text
# 2                                             no_text
# 3                                             no_text
# 4                                             no_text
# 5                                             no_text
# 6                                             no_text
# 7                                             no_text
# 8                                             no_text
# 9                                             no_text
# 10                                          equipment
# 11                                            no_text
# 12                                            no_text
# 13          certificated employees salaries and wages
# 14                                            no_text
# 15         salaries and wages for substitute teachers
# 16                                            no_text
# 17                                            no_text
# 18                                            no_text
# 19                     travel mileage meeting expense
# 20                                 purchased services
# 21                                            no_text
# 22          certificated employees salaries and wages
# 23                                            no_text
# 24                                            no_text
# 25                                            no_text
# 26                                          equipment
# 27                                            no_text
# 28                                            no_text
# 29      extra duty pay overtime for support personnel
# ...                                               ...
# 400247      certificated employees salaries and wages
# 400248  extra duty pay overtime for support personnel
# 400249                                        no_text
# 400250                                        no_text
# 400251                                        no_text
# 400252                                        no_text
# 400253                                        no_text
# 400254                                        no_text
# 400255                                        no_text
# 400256                                        no_text
# 400257           travel and subsistence employee only
# 400258                                        no_text
# 400259                                        no_text
# 400260                                        no_text
# 400261                                        no_text
# 400262                                        no_text
# 400263                                        no_text
# 400264                           pupil transportation
# 400265  extra duty pay overtime for support personnel
# 400266                                        no_text
# 400267                                        no_text
# 400268                                        no_text
# 400269        salaries or wages for support personnel
# 400270                              awards and prizes
# 400271                                        no_text
# 400272                                        no_text
# 400273                                        no_text
# 400274                                        no_text
# 400275                                        no_text
# 400276     inservice substitute teachers grant funded
#
#                                           Text_1  \
# 0                                        no_text
# 1                  building improvement services
# 2                                        no_text
# 3                            regular instruction
# 4                            regular instruction
# 5                              employee benefits
# 6                                        no_text
# 7                                   undesignated
# 8                            regular instruction
# 9                            regular instruction
# 10                       itemai city yth emp opp
# 11                                       no_text
# 12                                       no_text
# 13                                       title i
# 14                                       no_text
# 15                                   regular pay
# 16                                  teacher lead
# 17                               safety security
# 18                  operation and maint of plant
# 19                          resp sexual behavior
# 20                           home team marketing
# 21                           regular instruction
# 22                          building allocations
# 23                                       no_text
# 24                                       no_text
# 25                    esea title i disadvantaged
# 26                     key bank national associa
# 27                           instructional staff
# 28                           regular instruction
# 29                 addl regular pay not smoothed
# ...                                          ...
# 400247                    psychological services
# 400248                                  overtime
# 400249                       regular instruction
# 400250                         special education
# 400251                       regular instruction
# 400252  individuals with disabilities act part b
# 400253                       regular instruction
# 400254                       regular instruction
# 400255                       regular instruction
# 400256                         employee benefits
# 400257                                   no_text
# 400258                                   no_text
# 400259                                   no_text
# 400260                                     other
# 400261                                   no_text
# 400262                       instructional staff
# 400263                       regular instruction
# 400264                     items foundation june
# 400265                                  overtime
# 400266                                   no_text
# 400267                       regular instruction
# 400268                                   no_text
# 400269                               regular pay
# 400270                  school improv incentives
# 400271                       instructional staff
# 400272                 staff dev and instr media
# 400273                       instructional staff
# 400274                                   no_text
# 400275                       instructional staff
# 400276                             miscellaneous
#
#                                Text_2       Text_3  \
# 0                             no_text      no_text
# 1                   bond expenditures      regular
# 2                             no_text      no_text
# 3                        teacher subs      regular
# 4                        teacher subs  alternative
# 5                             no_text      no_text
# 6       special education instruction      no_text
# 7                             no_text      no_text
# 8                             no_text      regular
# 9                        teacher subs      regular
# 10                            no_text      no_text
# 11                            no_text      no_text
# 12                            no_text      no_text
# 13                            no_text      no_text
# 14                            no_text      no_text
# 15                            no_text      no_text
# 16                            no_text      no_text
# 17                           adm prof      no_text
# 18               operations utilities      regular
# 19                            no_text      no_text
# 20                            no_text      no_text
# 21                       teacher subs      regular
# 22                            teacher      no_text
# 23                            no_text      no_text
# 24                            no_text      no_text
# 25                            no_text      no_text
# 26                            no_text      no_text
# 27                            no_text      regular
# 28                            no_text      regular
# 29                            no_text      no_text
# ...                               ...          ...
# 400247                     teachersup      no_text
# 400248                        no_text      no_text
# 400249                   teacher subs      no_text
# 400250            severe disabilities      regular
# 400251                        no_text      regular
# 400252                        no_text      no_text
# 400253                        no_text      regular
# 400254                        no_text      regular
# 400255                        no_text      regular
# 400256                        no_text      no_text
# 400257                        no_text      no_text
# 400258                        no_text      no_text
# 400259                        no_text      no_text
# 400260                        no_text      no_text
# 400261                        no_text      no_text
# 400262                   math science      no_text
# 400263                        no_text      regular
# 400264                        no_text      no_text
# 400265                        no_text      no_text
# 400266                        no_text      no_text
# 400267                        no_text   turnaround
# 400268                        no_text      no_text
# 400269                        no_text      no_text
# 400270                        no_text      no_text
# 400271                   math science      no_text
# 400272                        no_text      no_text
# 400273                        no_text      regular
# 400274                        no_text      no_text
# 400275  educational resource services      no_text
# 400276                        no_text      no_text
#
#                                     Text_4  \
# 0                                  no_text
# 1                                  no_text
# 2                      regular instruction
# 3                                  no_text
# 4                                  no_text
# 5                                  no_text
# 6                                  no_text
# 7                                  no_text
# 8                                  no_text
# 9                                  no_text
# 10                                 no_text
# 11                                 no_text
# 12                     regular instruction
# 13                                 no_text
# 14                                 no_text
# 15                                 no_text
# 16                                 no_text
# 17                                 no_text
# 18                                 no_text
# 19                                 no_text
# 20                                 no_text
# 21                                 no_text
# 22                                 no_text
# 23                                 no_text
# 24                     regular instruction
# 25                                sig arra
# 26                                 no_text
# 27                                 no_text
# 28                                 no_text
# 29              transportation bus drivers
# ...                                    ...
# 400247                             no_text
# 400248                             no_text
# 400249                             no_text
# 400250                             no_text
# 400251                             no_text
# 400252                         idea part b
# 400253                             no_text
# 400254                             no_text
# 400255                             no_text
# 400256                             no_text
# 400257                             no_text
# 400258                             no_text
# 400259                             no_text
# 400260                     state tif grant
# 400261                 office of principal
# 400262                             no_text
# 400263                             no_text
# 400264                             no_text
# 400265          transportation second runs
# 400266                             no_text
# 400267                             no_text
# 400268                 regular instruction
# 400269                       undistributed
# 400270                             no_text
# 400271                             no_text
# 400272                             no_text
# 400273                             no_text
# 400274                             no_text
# 400275                             no_text
# 400276  multilingual dist prof development
#
#                                                  combined
# 0       no_text no_text general fund teacher elementar...
# 1       no_text rgn gob no_text blank no_text contract...
# 2       no_text no_text general purpose school tcher 2...
# 3       no_text unalloc budgets schools no_text teache...
# 4       no_text non project no_text teacher secondary ...
# 5       no_text non project no_text custodian pt jobs ...
# 6       no_text no_text local fund no_text no_text edu...
# 7       no_text non project no_text sub manager food s...
# 8       no_text ela s teaching spanish only no_text te...
# 9       no_text unalloc budgets schools no_text teache...
# 10      no_text state and federal projects coordinatio...
# 11      no_text instruction general fund no_text no_te...
# 12      position control pools no_text general purpose...
# 13      no_text disadvantaged youth title i disadvanta...
# 14      no_text basic fefp k 12 conversion charter sch...
# 15      all campus payroll instruction general operati...
# 16      no_text basic fefp k 12 general fund teacher t...
# 17      no_text security services general admin lieute...
# 18      no_text non project no_text blank no_text elec...
# 19      no_text instruction and curriculum development...
# 20      no_text direction of support services pupils s...
# 21      no_text unalloc budgets schools no_text teache...
# 22      no_text disadvantaged youth title i disadvanta...
# 23      no_text guidance services conversion charter s...
# 24      no_text no_text general purpose school no_text...
# 25      no_text no_text school federal projects tcher ...
# 26      no_text instruction and curriculum development...
# 27      no_text core matters no_text teacher short ter...
# 28      no_text ela e teaching sheltered eng no_text t...
# 29      transportation department transportation gener...
# ...                                                   ...
# 400247  no_text psychological services general psychol...
# 400248  new construction department administration fac...
# 400249  no_text unalloc budgets schools no_text teache...
# 400250  no_text special ed severe needs no_text teache...
# 400251  no_text ela s teaching spanish only no_text te...
# 400252  teacher supply no_text school federal projects...
# 400253  no_text title iii ela no_text ela general assi...
# 400254  no_text read to achieve round three no_text te...
# 400255  no_text title i no_text ela general assignment...
# 400256  no_text non project no_text teacher elementary...
# 400257  vocational curriculum development and instruct...
# 400258  no_text basic fefp k 12 conversion charter sch...
# 400259  no_text staff services extended learning cente...
# 400260  no_text no_text school federal projects no_tex...
# 400261  no_text no_text general purpose school assista...
# 400262  no_text title ii part a teacher qualit no_text...
# 400263  no_text ela e teaching sheltered eng no_text t...
# 400264  no_text instruction and curriculum development...
# 400265  transportation department transportation gener...
# 400266  no_text instruction general fund no_text no_te...
# 400267  no_text ns gob no_text secondary spec ed para ...
# 400268  no_text no_text general purpose school no_text...
# 400269  child nutrition food services child nutrition ...
# 400270  no_text other improvements of instruction serv...
# 400271  no_text title ii part a teacher qualit no_text...
# 400272  no_text inst staff training svcs general fund ...
# 400273  no_text title ii d no_text teacher retrd shrt ...
# 400274  no_text no_text schoolwide schools school liai...
# 400275  no_text non project no_text library technician...
# 400276  instruction and curriculum instruction title p...
#
# [400277 rows x 15 columns]
#            Facility_or_Department  \
# 0                         no_text
# 1                         no_text
# 2                         no_text
# 3                         no_text
# 4                         no_text
# 5                         no_text
# 6                         no_text
# 7                         no_text
# 8                         no_text
# 9                         no_text
# 10                        no_text
# 11                        no_text
# 12                        no_text
# 13                        no_text
# 14                        no_text
# 15                        no_text
# 16                        no_text
# 17                        no_text
# 18                        no_text
# 19                        no_text
# 20                        no_text
# 21                        no_text
# 22                        no_text
# 23                        no_text
# 24                        no_text
# 25                        no_text
# 26                        no_text
# 27                        no_text
# 28                        no_text
# 29                        no_text
# ...                           ...
# 50034  instruction and curriculum
# 50035                 warehousing
# 50036          all campus payroll
# 50037          all campus payroll
# 50038          all campus payroll
# 50039  instruction and curriculum
# 50040                     no_text
# 50041          all campus payroll
# 50042          all campus payroll
# 50043          all campus payroll
# 50044  instruction and curriculum
# 50045          all campus payroll
# 50046                     no_text
# 50047  instruction and curriculum
# 50048         gifted and talented
# 50049          all campus payroll
# 50050  instruction and curriculum
# 50051  instruction and curriculum
# 50052  instruction and curriculum
# ...
# 25                                   no_text
# 26                                   no_text
# 27                                   no_text
# 28                                   no_text
# 29                                   no_text
# ...                                      ...
# 50034  title part a improving basic programs
# 50035                             operations
# 50036                             operations
# 50037                             operations
# 50038                             operations
# 50039       student success initiative grant
# 50040                                no_text
# 50041                             operations
# 50042                             operations
# 50043                             operations
# 50044               title school improvement
# 50045                             operations
# 50046                             elementary
# 50047  title part a improving basic programs
# 50048                                no_text
# 50049                             operations
# 50050                                no_text
# 50051                                no_text
# 50052  title part a improving basic programs
# 50053                             operations
# 50054                             operations
# 50055                             operations
# 50056                        child nutrition
# 50057                                no_text
# 50058                                no_text
# 50059                                no_text
# 50060                                no_text
# 50061                                no_text
# 50062                                no_text
# 50063                                no_text
#
#                                   Sub_Object_Description  \
# 0               line item that is paid with campus money
# 1                                                general
# 2                                                general
# 3                                                general
# 4                                                general
# 5                                          magnet school
# 6                                                general
# 7                                                general
# 8                                                    art
# 9                                                general
# 10                                               general
# 11                                               general
# 12              line item that is paid with campus money
# 13                                               general
# 14                                               general
# 15                                               general
# 16                                               general
# 17                                               general
# 18                                               general
# 19              line item that is paid with campus money
# 20                                               general
# 21                                               general
# 22                                               general
# 23                                               general
# 24                                               general
# 25                                               general
# 26                                         language arts
# 27                                           boys tennis
# 28                                         solution team
# 29                                               general
# ...                                                  ...
# 50034                                      extended year
# 50035      extra duty pay overtime for support personnel
# 50036  salaries and wages for teachers and other prof...
# 50037            salaries or wages for support personnel
# 50038         salaries and wages for substitute teachers
# 50039                                      extended week
# 50040                      miscellaneous operating costs
# 50041  salaries and wages for teachers and other prof...
# 50042                           critical needs incentive
# 50043  salaries and wages for teachers and other prof...
# 50044                                       extended day
# 50045  salaries and wages for teachers and other prof...
# 50046      extra duty pay overtime for support personnel
# 50047                                      extended week
# 50048                                   general supplies
# 50049                               incentive supplement
# 50050                                   general supplies
# 50051                                 teacher retirement
# 50052                                           tutoring
# 50053      extra duty pay overtime for support personnel
# 50054      extra duty pay overtime for support personnel
# 50055              temporary part time support personnel
# 50056            salaries or wages for support personnel
# 50057    contracted maintenance and repair buildings and
# 50058                                   food hospitality
# 50059                                            no_text
# 50060                                            no_text
# 50061                                            no_text
# 50062                                            no_text
# 50063                                            no_text
#
#                           Text_1   Text_2   Text_3  \
# 0                        no_text  no_text  no_text
# 1                        no_text  no_text  no_text
# 2                        no_text  no_text  no_text
# 3                        no_text  no_text  no_text
# 4                        no_text  no_text  no_text
# 5                        no_text  no_text  no_text
# 6                        no_text  no_text  no_text
# 7                        no_text  no_text  no_text
# 8                        no_text  no_text  no_text
# 9                        no_text  no_text  no_text
# 10                       no_text  no_text  no_text
# 11                       no_text  no_text  no_text
# 12                       no_text  no_text  no_text
# 13                       no_text  no_text  no_text
# 14                       no_text  no_text  no_text
# 15                       no_text  no_text  no_text
# 16                       no_text  no_text  no_text
# 17                       no_text  no_text  no_text
# 18                       no_text  no_text  no_text
# 19                       no_text  no_text  no_text
# 20                       no_text  no_text  no_text
# 21                       no_text  no_text  no_text
# 22                       no_text  no_text  no_text
# 23                       no_text  no_text  no_text
# 24                       no_text  no_text  no_text
# 25                       no_text  no_text  no_text
# 26                       no_text  no_text  no_text
# 27                       no_text  no_text  no_text
# 28                       no_text  no_text  no_text
# 29                       no_text  no_text  no_text
# ...                          ...      ...      ...
# 50034              extended year  no_text  no_text
# 50035                   overtime  no_text  no_text
# 50036                regular pay  no_text  no_text
# 50037                regular pay  no_text  no_text
# 50038                regular pay  no_text  no_text
# 50039              miscellaneous  no_text  no_text
# 50040                    no_text  no_text  no_text
# 50041                regular pay  no_text  no_text
# 50042  critical needs supplement  no_text  no_text
# 50043                regular pay  no_text  no_text
# 50044              miscellaneous  no_text  no_text
# 50045                regular pay  no_text  no_text
# 50046              extended days  no_text  no_text
# 50047              extended days  no_text  no_text
# 50048                    no_text  no_text  no_text
# 50049            preformance pay  no_text  no_text
# 50050                    no_text  no_text  no_text
# 50051                    no_text  no_text  no_text
# 50052              extended days  no_text  no_text
# 50053                  extra run  no_text  no_text
# 50054                   overtime  no_text  no_text
# 50055                regular pay  no_text  no_text
# 50056                regular pay  no_text  no_text
# 50057                    no_text  no_text  no_text
# 50058                    no_text  no_text  no_text
# 50059                    no_text  no_text  no_text
# 50060                    no_text  no_text  no_text
# 50061                    no_text  no_text  no_text
# 50062                    no_text  no_text  no_text
# 50063                    no_text  no_text  no_text
#
#                                               Text_4  \
# 0                                            no_text
# 1                                            no_text
# 2                                            no_text
# 3                                            no_text
# 4                                            no_text
# 5                                            no_text
# 6                                            no_text
# 7                                            no_text
# 8                                            no_text
# 9                                            no_text
# 10                                           no_text
# 11                                           no_text
# 12                                           no_text
# 13                                           no_text
# 14                                           no_text
# 15                                           no_text
# 16                                           no_text
# 17                                           no_text
# 18                                           no_text
# 19                                           no_text
# 20                                           no_text
# 21                                           no_text
# 22                                           no_text
# 23                                           no_text
# 24                                           no_text
# 25                                           no_text
# 26                                           no_text
# 27                                           no_text
# 28                                           no_text
# 29                                           no_text
# ...                                              ...
# 50034                                        no_text
# 50035                                        no_text
# 50036  basic educational services district objective
# 50037                                        no_text
# 50038                                        no_text
# 50039  basic educational services district objective
# 50040                                        no_text
# 50041  basic educational services district objective
# 50042                                        no_text
# 50043  basic educational services district objective
# 50044                                        no_text
# 50045  basic educational services district objective
# 50046                                        no_text
# 50047                                        no_text
# 50048                                        no_text
# 50049                                  undistributed
# 50050                                        no_text
# 50051                                     extra duty
# 50052                                        no_text
# 50053                     transportation second runs
# 50054                                        no_text
# 50055                                        no_text
# 50056                                  undistributed
# 50057                                        no_text
# 50058                                        no_text
# 50059                                        no_text
# 50060                                        no_text
# 50061                                        no_text
# 50062                                        no_text
# 50063                                        no_text
#
#                                                 combined
# 0      no_text instruction general fund no_text schoo...
# 1      no_text cocurricular extra curricular activiti...
# 2      no_text instruction general fund t el 1st bil ...
# 3      no_text instruction general fund t el 2nd bil ...
# 4      no_text school leadership general fund clerk i...
# 5      no_text school leadership general fund no_text...
# 6      no_text student transportation general fund no...
# 7      no_text guidance counseling and evaluation ser...
# 8      no_text instruction general fund no_text schoo...
# 9      no_text food services nat l schl breakfast lun...
# 10     no_text instruction general fund tchr asst sp ...
# 11     no_text instruction idea b formula tchr asst s...
# 12     no_text curriculum instructional staff develop...
# 13     no_text instruction general fund t hs p e scho...
# 14     no_text instruction general fund no_text schoo...
# 15     no_text instruction general fund t el 1st esl ...
# 16     no_text instruction general fund travel school...
# 17     no_text community services english literacy ci...
# 18     no_text instructional leadership general fund ...
# 19     no_text security monitoring servicess general ...
# 20     no_text cocurricular extra curricular activiti...
# 21     no_text instruction general fund no_text state...
# 22     no_text instruction general fund t el 4th esl ...
# 23     no_text instruction general fund t hs v fam co...
# 24     no_text data processing services general fund ...
# 25     no_text school leadership general fund elem as...
# 26     no_text instruction general fund no_text secon...
# 27     no_text cocurricular extra curricular activiti...
# 28     no_text curriculum instructional staff develop...
# 29     no_text instruction general fund english schoo...
# ...                                                  ...
# 50034  instruction and curriculum instruction title p...
# 50035  warehousing facilities maintenance and operati...
# 50036  all campus payroll instruction general operati...
# 50037  all campus payroll instruction general operati...
# 50038  all campus payroll instruction general operati...
# 50039  instruction and curriculum instruction intensi...
# 50040  no_text extracurricular activities campus acti...
# 50041  all campus payroll instruction general operati...
# 50042  all campus payroll instruction general operati...
# 50043  all campus payroll instruction general operati...
# 50044  instruction and curriculum instruction title p...
# 50045  all campus payroll instruction general operati...
# 50046  no_text instruction campus activity funds clas...
# 50047  instruction and curriculum instruction title p...
# 50048  gifted and talented extracurricular activities...
# 50049  all campus payroll extracurricular activities ...
# 50050  instruction and curriculum instruction general...
# 50051  instruction and curriculum guidance counseling...
# 50052  instruction and curriculum instruction title p...
# 50053  transportation department transportation gener...
# 50054  custodial department facilities maintenance an...
# 50055  textbook department facilities maintenance and...
# 50056  child nutrition food services child nutrition ...
# 50057  custodial department facilities maintenance an...
# 50058  no_text school leadership campus activity fund...
# 50059  no_text no_text general fund clinic assistant ...
# 50060  no_text no_text general fund clinic assistant ...
# 50061  no_text no_text general fund clinic assistant ...
# 50062  no_text no_text general fund clinic assistant ...
# 50063  no_text no_text general fund clinic assistant ...
#
# [50064 rows x 15 columns]

# %%
#conversion of text data values to numbers using hashing technique
tfidf = txt.TfidfVectorizer(ngram_range=(1,2), max_df=1.0, min_df=10)
hsv = txt.HashingVectorizer()


tfidf.fit(training_data['combined'])
hsv.fit(test_data['combined'])

X_tfidf = tfidf.transform(training_data['combined'])
X_test_tfidf = tfidf.transform(test_data['combined'])

X_hsv = hsv.transform(training_data['combined'])
X_test_hsv = hsv.transform(test_data['combined'])

X = sparse.hstack((X_hsv, X_tfidf))
X_test = sparse.hstack((X_test_hsv, X_test_tfidf))

# %%
prediction1 = []
prediction2 = []
prediction3 = []
prediction4 = []

# %%
#SGD model training and prediction
for i in range(len(cols)):
    print ("label = ", i)
    sgd1 = linear_model.SGDClassifier(loss = 'log', max_iter = 120, alpha = 0.000001)
    sgd2 = linear_model.SGDClassifier(loss = 'log', max_iter = 120, penalty = 'l1')
    sgd3 = linear_model.SGDClassifier(loss = 'log', max_iter = 120, penalty = 'l2')
    sgd4 = linear_model.SGDClassifier(loss = 'log', max_iter = 120, penalty = 'elasticnet')
    sgd1.fit(X, labels.iloc[:,i])
    sgd2.fit(X, labels.iloc[:,i])
    sgd3.fit(X, labels.iloc[:,i])
    sgd4.fit(X, labels.iloc[:,i])
    if i == 0:
        prediction1 = sgd1.predict_proba(X_test)
        prediction2 = sgd2.predict_proba(X_test)
        prediction3 = sgd3.predict_proba(X_test)
        prediction4 = sgd4.predict_proba(X_test)
    else:
        print(len(prediction1),len(sgd1.predict_proba(X_test)))
        prediction1 = np.hstack((prediction1,sgd1.predict_proba(X_test)))
        prediction2 = np.hstack((prediction2,sgd2.predict_proba(X_test)))
        prediction3 = np.hstack((prediction3,sgd3.predict_proba(X_test)))
        prediction4 = np.hstack((prediction4,sgd4.predict_proba(X_test)))
        
preds = (prediction1 + prediction2 + prediction3 + prediction4)/4.0

for i in range(1, len(sample.columns)):
    colname = sample.columns[i]
    sample[str(colname)] = preds[:,i-1]

sample.to_csv('submitpreds.csv', index = False)
# Out:
# label =  0
# label =  1
# 50064 50064
# label =  2
# 50064 50064
# label =  3
# 50064 50064
# label =  4
# 50064 50064
# label =  5
# 50064 50064
# label =  6
# 50064 50064
# label =  7
# 50064 50064
# label =  8
# 50064 50064
